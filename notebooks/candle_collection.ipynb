# %% [markdown]
# ## Description
#
# Must get 1 minute candles from Binance USDT perps for the symbols in filtered_tokens.csv.
# Must take in a parameter which specifies how many symbols to get data from. If this parameter is None then get all of them.
# Populate the 1 minute candles according to the Candle dataclass in models.py.
# Must respect rate limits. Should be complex and look at the rate limit data in the responses and adjust accordingly
# Must allow for a date range input. Not all the tokens would have been listed during the entire period so it needs to be able to figure out the data range within the date range for each symbol.
# Output to data folder.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import requests
import time
import asyncio
import aiohttp
from datetime import datetime, timedelta
from pathlib import Path
import sys
import os
from concurrent.futures import ThreadPoolExecutor
import threading

# Add the backtester module to the path
sys.path.append('/home/zac/back-testing')
from backtester.models import Candle

# Configuration
BINANCE_BASE_URL = "https://fapi.binance.com"
DATA_DIR = Path("/home/zac/back-testing/data")
TOKENS_FILE = DATA_DIR / "filtered_tokens.csv"

print("Libraries imported successfully!")
print(f"Data directory: {DATA_DIR}")
print(f"Tokens file: {TOKENS_FILE}")
# Out:
# Libraries imported successfully!
# Data directory: /home/zac/back-testing/data
# Tokens file: /home/zac/back-testing/data/filtered_tokens.csv

# %%
class BinanceRateLimiter:
    """Handle Binance API rate limiting with automatic adjustment and concurrent support"""
    
    def __init__(self, max_concurrent_requests=10):
        self.weight_limit = 2400  # Default weight limit per minute
        self.current_weight = 0
        self.window_start = time.time()
        self.min_delay = 0.05  # Reduced minimum delay (50ms)
        self.last_request_time = 0
        self.max_concurrent = max_concurrent_requests
        self.semaphore = threading.Semaphore(max_concurrent_requests)
        self.lock = threading.Lock()
        
    def check_rate_limits(self, response_headers):
        """Update rate limit info from response headers"""
        with self.lock:
            if 'x-mbx-used-weight-1m' in response_headers:
                self.current_weight = int(response_headers['x-mbx-used-weight-1m'])
                
            # If we're approaching the limit, implement backoff
            if self.current_weight > self.weight_limit * 0.7:  # 70% of limit
                print(f"Rate limit warning: {self.current_weight}/{self.weight_limit}")
            
    def wait_if_needed(self):
        """Wait if necessary to respect rate limits"""
        with self.lock:
            current_time = time.time()
            
            # Reset weight counter every minute
            if current_time - self.window_start >= 60:
                self.current_weight = 0
                self.window_start = current_time
                
            # Ensure minimum delay between requests
            time_since_last = current_time - self.last_request_time
            if time_since_last < self.min_delay:
                time.sleep(self.min_delay - time_since_last)
                
            # If weight is high, wait longer
            if self.current_weight > self.weight_limit * 0.8:
                wait_time = 60 - (current_time - self.window_start)
                if wait_time > 0:
                    print(f"Rate limit reached. Waiting {wait_time:.1f} seconds...")
                    time.sleep(wait_time)
                    self.current_weight = 0
                    self.window_start = time.time()
                    
            self.last_request_time = time.time()
    
    def acquire(self):
        """Acquire semaphore for concurrent request limiting"""
        self.semaphore.acquire()
        
    def release(self):
        """Release semaphore"""
        self.semaphore.release()

rate_limiter = BinanceRateLimiter(max_concurrent_requests=4)  # Conservative concurrent limit
print("Rate limiter initialized with concurrent support")
# Out:
# Rate limiter initialized with concurrent support

# %%
def get_symbol_info(symbol):
    """Get symbol information to determine listing date and availability"""
    rate_limiter.wait_if_needed()
    
    try:
        url = f"{BINANCE_BASE_URL}/fapi/v1/exchangeInfo"
        response = requests.get(url)
        response.raise_for_status()
        
        rate_limiter.check_rate_limits(response.headers)
        
        data = response.json()
        
        # Find the specific symbol
        for symbol_info in data['symbols']:
            if symbol_info['symbol'] == symbol:
                return {
                    'symbol': symbol,
                    'status': symbol_info['status'],
                    'onboardDate': symbol_info.get('onboardDate', None),
                    'contractType': symbol_info.get('contractType', 'PERPETUAL')
                }
        
        return None
        
    except requests.RequestException as e:
        print(f"Error getting symbol info for {symbol}: {e}")
        return None

def get_earliest_valid_timestamp(symbol, start_date):
    """Get the earliest valid timestamp for a symbol, considering listing date"""
    symbol_info = get_symbol_info(symbol)
    
    if not symbol_info or symbol_info['status'] != 'TRADING':
        print(f"Symbol {symbol} is not available for trading")
        return None
    
    # Convert start_date to timestamp
    if isinstance(start_date, str):
        start_dt = datetime.strptime(start_date, "%Y-%m-%d")
    else:
        start_dt = start_date
    
    # If symbol has onboard date, use the later of the two dates
    if symbol_info.get('onboardDate'):
        onboard_dt = datetime.fromtimestamp(symbol_info['onboardDate'] / 1000)
        earliest_dt = max(start_dt, onboard_dt)
    else:
        earliest_dt = start_dt
    
    return int(earliest_dt.timestamp() * 1000)

print("Symbol info functions defined")
# Out:
# Symbol info functions defined

# %%
def get_klines_batch(symbol, start_time, end_time, limit=1000):
    """Get klines for a specific time period with concurrent support"""
    rate_limiter.acquire()
    
    try:
        rate_limiter.wait_if_needed()
        
        url = f"{BINANCE_BASE_URL}/fapi/v1/klines"
        params = {
            'symbol': symbol,
            'interval': '1m',
            'startTime': start_time,
            'endTime': end_time,
            'limit': limit
        }
        
        response = requests.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        rate_limiter.check_rate_limits(response.headers)
        
        return response.json()
        
    except requests.RequestException as e:
        print(f"Error getting klines for {symbol}: {e}")
        return []
    finally:
        rate_limiter.release()

def convert_kline_to_candle(kline_data, symbol):
    """Convert Binance kline data to Candle object"""
    return Candle(
        symbol=symbol,
        timestamp=datetime.fromtimestamp(int(kline_data[0]) / 1000),
        open=np.float64(kline_data[1]),
        high=np.float64(kline_data[2]),
        low=np.float64(kline_data[3]),
        close=np.float64(kline_data[4]),
        volume=np.float64(kline_data[5])
    )

def get_candle_batch_worker(args):
    """Worker function for concurrent batch processing"""
    symbol, start_timestamp, end_timestamp, batch_num = args
    
    try:
        klines = get_klines_batch(symbol, start_timestamp, end_timestamp)
        if klines:
            candles = [convert_kline_to_candle(kline, symbol) for kline in klines]
            return batch_num, candles, klines[-1][0]  # Return batch number, candles, and last timestamp
        return batch_num, [], None
    except Exception as e:
        print(f"Error in batch {batch_num} for {symbol}: {e}")
        return batch_num, [], None

def get_all_candles_for_symbol(symbol, start_date, end_date):
    """Get all 1-minute candles for a symbol within date range using concurrent processing"""
    print(f"Getting data for {symbol}...")
    
    # Get the earliest valid timestamp for this symbol
    start_timestamp = get_earliest_valid_timestamp(symbol, start_date)
    if not start_timestamp:
        print(f"Skipping {symbol}: not available")
        return []
    
    # Convert end_date to timestamp
    if isinstance(end_date, str):
        end_dt = datetime.strptime(end_date, "%Y-%m-%d")
    else:
        end_dt = end_date
    end_timestamp = int(end_dt.timestamp() * 1000)
    
    print(f"  Date range: {datetime.fromtimestamp(start_timestamp/1000)} to {end_dt}")
    
    # Create batches for concurrent processing
    batch_tasks = []
    current_start = start_timestamp
    batch_num = 0
    
    while current_start < end_timestamp:
        current_end = min(current_start + (1000 * 60 * 1000), end_timestamp)
        batch_tasks.append((symbol, current_start, current_end, batch_num))
        current_start = current_end
        batch_num += 1
    
    print(f"  Processing {len(batch_tasks)} batches concurrently...")
    
    # Process batches concurrently
    all_candles = []
    with ThreadPoolExecutor(max_workers=6) as executor:  # Conservative worker count
        batch_results = list(executor.map(get_candle_batch_worker, batch_tasks))
    
    # Sort results by batch number and combine
    batch_results.sort(key=lambda x: x[0])
    
    for batch_num, candles, last_timestamp in batch_results:
        if candles:
            all_candles.extend(candles)
            print(f"  Batch {batch_num}: {len(candles)} candles")
    
    print(f"  Completed {symbol}: {len(all_candles)} total candles")
    return all_candles

print("Concurrent candle collection functions defined")
# Out:
# Concurrent candle collection functions defined

# %%
def save_candles_to_csv(candles, symbol, data_dir):
    """Save candles to CSV file in the data directory"""
    if not candles:
        print(f"No candles to save for {symbol}")
        return
    
    # Create DataFrame
    df_data = []
    for candle in candles:
        df_data.append({
            'timestamp': candle.timestamp,
            'open': candle.open,
            'high': candle.high,
            'low': candle.low,
            'close': candle.close,
            'volume': candle.volume
        })
    
    df = pd.DataFrame(df_data)
    
    # Sort by timestamp to ensure chronological order
    df = df.sort_values('timestamp')
    
    # Save to CSV
    output_file = data_dir / f"{symbol}.csv"
    df.to_csv(output_file, index=False)
    
    print(f"Saved {len(df)} candles for {symbol} to {output_file}")

def load_filtered_tokens(tokens_file, max_symbols=None):
    """Load symbols from filtered_tokens.csv"""
    df = pd.read_csv(tokens_file)
    symbols = df['binance_symbol'].tolist()
    
    if max_symbols is not None:
        symbols = symbols[:max_symbols]
        print(f"Limited to first {max_symbols} symbols")
    
    print(f"Loaded {len(symbols)} symbols from {tokens_file}")
    return symbols

print("Utility functions defined")
# Out:
# Utility functions defined

# %%
def process_symbol_worker(args):
    """Worker function for processing individual symbols concurrently"""
    symbol, start_date, end_date, symbol_index, total_symbols = args
    
    print(f"\n[{symbol_index}/{total_symbols}] Processing {symbol}")
    
    try:
        # Collect candles for this symbol
        candles = get_all_candles_for_symbol(symbol, start_date, end_date)
        
        if candles:
            # Save to CSV
            save_candles_to_csv(candles, symbol, DATA_DIR)
            return symbol, True, len(candles)
        else:
            print(f"  No candles collected for {symbol}")
            return symbol, False, 0
            
    except Exception as e:
        print(f"  Error processing {symbol}: {e}")
        return symbol, False, 0

def collect_candle_data(start_date="2024-01-01", end_date="2024-12-31", max_symbols=None, max_concurrent_symbols=3):
    """
    Main function to collect candle data for multiple symbols with concurrent processing
    
    Args:
        start_date: Start date in YYYY-MM-DD format or datetime object
        end_date: End date in YYYY-MM-DD format or datetime object  
        max_symbols: Maximum number of symbols to process (None for all)
        max_concurrent_symbols: Maximum number of symbols to process concurrently
    """
    
    print("=== Binance USDT Perpetual Futures Candle Collection (Concurrent) ===")
    print(f"Date range: {start_date} to {end_date}")
    print(f"Max concurrent symbols: {max_concurrent_symbols}")
    
    # Load symbols
    symbols = load_filtered_tokens(TOKENS_FILE, max_symbols)
    
    # Ensure data directory exists
    DATA_DIR.mkdir(exist_ok=True)
    
    successful_collections = 0
    failed_collections = 0
    total_candles = 0
    
    # Process symbols in batches to avoid overwhelming the API
    symbol_tasks = []
    for i, symbol in enumerate(symbols, 1):
        symbol_tasks.append((symbol, start_date, end_date, i, len(symbols)))
    
    # Process symbols concurrently in batches
    batch_size = max_concurrent_symbols
    for i in range(0, len(symbol_tasks), batch_size):
        batch = symbol_tasks[i:i + batch_size]
        
        print(f"\nProcessing batch {i//batch_size + 1}/{(len(symbol_tasks) + batch_size - 1)//batch_size}")
        
        with ThreadPoolExecutor(max_workers=max_concurrent_symbols) as executor:
            results = list(executor.map(process_symbol_worker, batch))
        
        # Process results
        for symbol, success, candle_count in results:
            if success:
                successful_collections += 1
                total_candles += candle_count
            else:
                failed_collections += 1
        
        # Small delay between batches to be respectful
        if i + batch_size < len(symbol_tasks):
            time.sleep(2)
    
    print(f"\n=== Collection Summary ===")
    print(f"Successfully collected: {successful_collections}")
    print(f"Failed: {failed_collections}")
    print(f"Total symbols processed: {len(symbols)}")
    print(f"Total candles collected: {total_candles}")
    print(f"Data saved to: {DATA_DIR}")

print("Concurrent main collection function defined")
# Out:
# Concurrent main collection function defined

# %% [markdown]
# ## Usage Examples
#
# Below are several examples of how to use the candle collection system:

# %%
# Example 1: Test with 3 symbols concurrently (last 52 weeks)
from datetime import datetime, timedelta
end_date = datetime.now()
start_date = end_date - timedelta(weeks=52)

# Test with concurrent processing - this should be much faster!
collect_candle_data(start_date=start_date, end_date=end_date, max_symbols=3, max_concurrent_symbols=2)

print("Example 1 ready (test with 3 symbols, last 52 weeks, 2 concurrent)")
# Out:
# === Binance USDT Perpetual Futures Candle Collection (Concurrent) ===
# Date range: 2024-10-18 09:48:06.705662 to 2025-10-17 09:48:06.705662
# Max concurrent symbols: 2
# Limited to first 3 symbols
# Loaded 3 symbols from /home/zac/back-testing/data/filtered_tokens.csv
#
# Processing batch 1/2
#
# [1/3] Processing RLCUSDT
# Getting data for RLCUSDT...
#
# [2/3] Processing BANKUSDT
# Getting data for BANKUSDT...
#   Date range: 2024-10-18 09:48:06.705000 to 2025-10-17 09:48:06.705662
#   Processing 525 batches concurrently...
#   Date range: 2025-04-18 20:30:00 to 2025-10-17 09:48:06.705662
#   Processing 262 batches concurrently...
#   Date range: 2024-10-18 09:48:06.705000 to 2025-10-17 09:48:06.705662
#   Processing 525 batches concurrently...
#   Date range: 2025-04-18 20:30:00 to 2025-10-17 09:48:06.705662
#   Processing 262 batches concurrently...
# Rate limit warning: 1685/2400
# Rate limit warning: 1690/2400
# Rate limit warning: 1685/2400
# Rate limit warning: 1690/2400
# Rate limit warning: 1695/2400
# Rate limit warning: 1700/2400
# Rate limit warning: 1695/2400
# Rate limit warning: 1700/2400
# Rate limit warning: 1705/2400
# Rate limit warning: 1710/2400
# Rate limit warning: 1715/2400
# Rate limit warning: 1720/2400
# Rate limit warning: 1705/2400
# Rate limit warning: 1710/2400
# Rate limit warning: 1715/2400
# Rate limit warning: 1720/2400
# Rate limit warning: 1725/2400
# Rate limit warning: 1730/2400
# Rate limit warning: 1735/2400
# Rate limit warning: 1725/2400
# Rate limit warning: 1730/2400
# Rate limit warning: 1735/2400
# Rate limit warning: 1740/2400
# Rate limit warning: 1745/2400
# Rate limit warning: 1740/2400
# Rate limit warning: 1745/2400
# Rate limit warning: 1750/2400
# Rate limit warning: 1755/2400
# Rate limit warning: 1760/2400
# Rate limit warning: 1750/2400
# Rate limit warning: 1755/2400
# Rate limit warning: 1760/2400
# Rate limit warning: 1765/2400
# Rate limit warning: 1771/2400
# Rate limit warning: 1776/2400
# Rate limit warning: 1765/2400
# Rate limit warning: 1771/2400
# Rate limit warning: 1776/2400
# Rate limit warning: 1781/2400
# Rate limit warning: 1786/2400
# Rate limit warning: 1781/2400
# Rate limit warning: 1786/2400
# Rate limit warning: 1791/2400
# Rate limit warning: 1796/2400
# Rate limit warning: 1801/2400
# Rate limit warning: 1791/2400
# Rate limit warning: 1796/2400
# Rate limit warning: 1801/2400
# Rate limit warning: 1806/2400
# Rate limit warning: 1811/2400
# Rate limit warning: 1816/2400
# Rate limit warning: 1806/2400
# Rate limit warning: 1811/2400
# Rate limit warning: 1816/2400
# Rate limit warning: 1821/2400
# Rate limit warning: 1827/2400
# Rate limit warning: 1821/2400
# Rate limit warning: 1827/2400
# Rate limit warning: 1832/2400
# Rate limit warning: 1837/2400
# Rate limit warning: 1842/2400
# Rate limit warning: 1832/2400
# Rate limit warning: 1837/2400
# Rate limit warning: 1842/2400
# Rate limit warning: 1847/2400
# Rate limit warning: 1853/2400
# Rate limit warning: 1858/2400
# Rate limit warning: 1847/2400
# Rate limit warning: 1853/2400
# Rate limit warning: 1858/2400
# Rate limit warning: 1863/2400
# Rate limit warning: 1868/2400
# Rate limit warning: 1863/2400
# Rate limit warning: 1868/2400
# Rate limit warning: 1873/2400
# Rate limit warning: 1878/2400
# Rate limit warning: 1883/2400
# Rate limit warning: 1873/2400
# Rate limit warning: 1878/2400
# Rate limit warning: 1883/2400
# Rate limit warning: 1888/2400
# Rate limit warning: 1893/2400
# Rate limit warning: 1898/2400
# Rate limit warning: 1888/2400
# Rate limit warning: 1893/2400
# Rate limit warning: 1898/2400
# Rate limit warning: 1903/2400
# Rate limit warning: 1908/2400
# Rate limit warning: 1903/2400
# Rate limit warning: 1908/2400
# Rate limit warning: 1913/2400
# Rate limit warning: 1918/2400
# Rate limit warning: 1923/2400
# Rate limit reached. Waiting 23.5 seconds...
# Rate limit warning: 1913/2400
# Rate limit warning: 1918/2400
# Rate limit warning: 1923/2400
# Rate limit reached. Waiting 23.5 seconds...
# Rate limit warning: 1928/2400
# Rate limit warning: 1933/2400
# Rate limit warning: 1938/2400
# Rate limit reached. Waiting 60.0 seconds...
# Rate limit warning: 1928/2400
# Rate limit warning: 1933/2400
# Rate limit warning: 1938/2400
# Rate limit reached. Waiting 60.0 seconds...
#   Batch 0: 1000 candles
#   Batch 1: 1000 candles
#   Batch 2: 1000 candles
#   Batch 3: 1000 candles
#   Batch 4: 1000 candles
#   Batch 5: 1000 candles
#   Batch 6: 1000 candles
#   Batch 7: 1000 candles
#   Batch 8: 1000 candles
#   Batch 9: 1000 candles
#   Batch 10: 1000 candles
#   Batch 11: 1000 candles
#   Batch 12: 1000 candles
#   Batch 13: 1000 candles
#   Batch 14: 1000 candles
#   Batch 15: 1000 candles
#   Batch 16: 1000 candles
#   Batch 17: 1000 candles
#   Batch 18: 1000 candles
#   Batch 19: 1000 candles
#   Batch 20: 1000 candles
#   Batch 21: 1000 candles
#   Batch 22: 1000 candles
#   Batch 23: 1000 candles
#   Batch 24: 1000 candles
#   Batch 25: 1000 candles
#   Batch 26: 1000 candles
#   Batch 27: 1000 candles
#   Batch 28: 1000 candles
#   Batch 29: 1000 candles
#   Batch 30: 1000 candles
#   Batch 31: 1000 candles
#   Batch 32: 1000 candles
#   Batch 33: 1000 candles
#   Batch 34: 1000 candles
#   Batch 35: 1000 candles
#   Batch 36: 1000 candles
#   Batch 37: 1000 candles
#   Batch 38: 1000 candles
#   Batch 39: 1000 candles
#   Batch 40: 1000 candles
#   Batch 41: 1000 candles
#   Batch 42: 1000 candles
#   Batch 43: 1000 candles
#   Batch 44: 1000 candles
#   Batch 45: 1000 candles
#   Batch 46: 1000 candles
#   Batch 47: 1000 candles
#   Batch 48: 1000 candles
#   Batch 49: 1000 candles
#   Batch 50: 1000 candles
#   Batch 51: 1000 candles
#   Batch 52: 1000 candles
#   Batch 53: 1000 candles
#   Batch 54: 1000 candles
#   Batch 55: 1000 candles
#   Batch 56: 1000 candles
#   Batch 57: 1000 candles
#   Batch 58: 1000 candles
#   Batch 59: 1000 candles
#   Batch 60: 1000 candles
#   Batch 61: 1000 candles
#   Batch 62: 1000 candles
#   Batch 63: 1000 candles
#   Batch 64: 1000 candles
#   Batch 65: 1000 candles
#   Batch 66: 1000 candles
#   Batch 67: 1000 candles
#   Batch 68: 1000 candles
#   Batch 69: 1000 candles
#   Batch 70: 1000 candles
#   Batch 71: 1000 candles
#   Batch 72: 1000 candles
#   Batch 73: 1000 candles
#   Batch 74: 1000 candles
#   Batch 75: 1000 candles
#   Batch 76: 1000 candles
#   Batch 77: 1000 candles
#   Batch 78: 1000 candles
#   Batch 79: 1000 candles
#   Batch 80: 1000 candles
#   Batch 81: 1000 candles
#   Batch 82: 1000 candles
#   Batch 83: 1000 candles
#   Batch 84: 1000 candles
#   Batch 85: 1000 candles
#   Batch 86: 1000 candles
#   Batch 87: 1000 candles
#   Batch 88: 1000 candles
#   Batch 89: 1000 candles
#   Batch 90: 1000 candles
#   Batch 91: 1000 candles
#   Batch 92: 1000 candles
#   Batch 93: 1000 candles
#   Batch 94: 1000 candles
#   Batch 95: 1000 candles
#   Batch 96: 1000 candles
#   Batch 97: 1000 candles
#   Batch 98: 1000 candles
#   Batch 99: 1000 candles
#   Batch 100: 1000 candles
#   Batch 101: 1000 candles
#   Batch 102: 1000 candles
#   Batch 103: 1000 candles
#   Batch 104: 1000 candles
#   Batch 105: 1000 candles
#   Batch 106: 1000 candles
#   Batch 107: 1000 candles
#   Batch 108: 1000 candles
#   Batch 109: 1000 candles
#   Batch 110: 1000 candles
#   Batch 111: 1000 candles
#   Batch 112: 1000 candles
#   Batch 113: 1000 candles
#   Batch 114: 1000 candles
#   Batch 115: 1000 candles
#   Batch 116: 1000 candles
#   Batch 117: 1000 candles
#   Batch 118: 1000 candles
#   Batch 119: 1000 candles
#   Batch 120: 1000 candles
#   Batch 121: 1000 candles
#   Batch 122: 1000 candles
#   Batch 123: 1000 candles
#   Batch 124: 1000 candles
#   Batch 125: 1000 candles
#   Batch 126: 1000 candles
#   Batch 127: 1000 candles
#   Batch 128: 1000 candles
#   Batch 129: 1000 candles
#   Batch 130: 1000 candles
#   Batch 131: 1000 candles
#   Batch 132: 1000 candles
#   Batch 133: 1000 candles
#   Batch 134: 1000 candles
#   Batch 135: 1000 candles
#   Batch 136: 1000 candles
#   Batch 137: 1000 candles
#   Batch 138: 1000 candles
#   Batch 139: 1000 candles
#   Batch 140: 1000 candles
#   Batch 141: 1000 candles
#   Batch 142: 1000 candles
#   Batch 143: 1000 candles
#   Batch 144: 1000 candles
#   Batch 145: 1000 candles
#   Batch 146: 1000 candles
#   Batch 147: 1000 candles
#   Batch 148: 1000 candles
#   Batch 149: 1000 candles
#   Batch 150: 1000 candles
#   Batch 151: 1000 candles
#   Batch 152: 1000 candles
#   Batch 153: 1000 candles
#   Batch 154: 1000 candles
#   Batch 155: 1000 candles
#   Batch 156: 1000 candles
#   Batch 157: 1000 candles
#   Batch 158: 1000 candles
#   Batch 159: 1000 candles
#   Batch 160: 1000 candles
#   Batch 161: 1000 candles
#   Batch 162: 1000 candles
#   Batch 163: 1000 candles
#   Batch 164: 1000 candles
#   Batch 165: 1000 candles
#   Batch 166: 1000 candles
#   Batch 167: 1000 candles
#   Batch 168: 1000 candles
#   Batch 169: 1000 candles
#   Batch 170: 1000 candles
#   Batch 171: 1000 candles
#   Batch 172: 1000 candles
#   Batch 173: 1000 candles
#   Batch 174: 1000 candles
#   Batch 175: 1000 candles
#   Batch 176: 1000 candles
#   Batch 177: 1000 candles
#   Batch 178: 1000 candles
#   Batch 179: 1000 candles
#   Batch 180: 1000 candles
#   Batch 181: 1000 candles
#   Batch 182: 1000 candles
#   Batch 183: 1000 candles
#   Batch 184: 1000 candles
#   Batch 185: 1000 candles
#   Batch 186: 1000 candles
#   Batch 187: 1000 candles
#   Batch 188: 1000 candles
#   Batch 189: 1000 candles
#   Batch 190: 1000 candles
#   Batch 191: 1000 candles
#   Batch 192: 1000 candles
#   Batch 193: 1000 candles
#   Batch 194: 1000 candles
#   Batch 195: 1000 candles
#   Batch 196: 1000 candles
#   Batch 197: 1000 candles
#   Batch 198: 1000 candles
#   Batch 199: 1000 candles
#   Batch 200: 1000 candles
#   Batch 201: 1000 candles
#   Batch 202: 1000 candles
#   Batch 203: 1000 candles
#   Batch 204: 1000 candles
#   Batch 205: 1000 candles
#   Batch 206: 1000 candles
#   Batch 207: 1000 candles
#   Batch 208: 1000 candles
#   Batch 209: 1000 candles
#   Batch 210: 1000 candles
#   Batch 211: 1000 candles
#   Batch 212: 1000 candles
#   Batch 213: 1000 candles
#   Batch 214: 1000 candles
#   Batch 215: 1000 candles
#   Batch 216: 1000 candles
#   Batch 217: 1000 candles
#   Batch 218: 1000 candles
#   Batch 219: 1000 candles
#   Batch 220: 1000 candles
#   Batch 221: 1000 candles
#   Batch 222: 1000 candles
#   Batch 223: 1000 candles
#   Batch 224: 1000 candles
#   Batch 225: 1000 candles
#   Batch 226: 1000 candles
#   Batch 227: 1000 candles
#   Batch 228: 1000 candles
#   Batch 229: 1000 candles
#   Batch 230: 1000 candles
#   Batch 231: 1000 candles
#   Batch 232: 1000 candles
#   Batch 233: 1000 candles
#   Batch 234: 1000 candles
#   Batch 235: 1000 candles
#   Batch 236: 1000 candles
#   Batch 237: 1000 candles
#   Batch 238: 1000 candles
#   Batch 239: 1000 candles
#   Batch 240: 1000 candles
#   Batch 241: 1000 candles
#   Batch 242: 1000 candles
#   Batch 243: 1000 candles
#   Batch 244: 1000 candles
#   Batch 245: 1000 candles
#   Batch 246: 1000 candles
#   Batch 247: 1000 candles
#   Batch 248: 1000 candles
#   Batch 249: 1000 candles
#   Batch 250: 1000 candles
#   Batch 251: 1000 candles
#   Batch 252: 1000 candles
#   Batch 253: 1000 candles
#   Batch 254: 1000 candles
#   Batch 255: 1000 candles
#   Batch 256: 1000 candles
#   Batch 257: 1000 candles
#   Batch 258: 1000 candles
#   Batch 259: 1000 candles
#   Batch 260: 1000 candles
#   Batch 261: 439 candles
#   Completed BANKUSDT: 261439 total candles
#   Batch 0: 1000 candles
#   Batch 1: 1000 candles
#   Batch 2: 1000 candles
#   Batch 3: 1000 candles
#   Batch 4: 1000 candles
#   Batch 5: 1000 candles
#   Batch 6: 1000 candles
#   Batch 7: 1000 candles
#   Batch 8: 1000 candles
#   Batch 9: 1000 candles
#   Batch 10: 1000 candles
#   Batch 11: 1000 candles
#   Batch 12: 1000 candles
#   Batch 13: 1000 candles
#   Batch 14: 1000 candles
#   Batch 15: 1000 candles
#   Batch 16: 1000 candles
#   Batch 17: 1000 candles
#   Batch 18: 1000 candles
#   Batch 19: 1000 candles
#   Batch 20: 1000 candles
#   Batch 21: 1000 candles
#   Batch 22: 1000 candles
#   Batch 23: 1000 candles
#   Batch 24: 1000 candles
#   Batch 25: 1000 candles
#   Batch 26: 1000 candles
#   Batch 27: 1000 candles
#   Batch 28: 1000 candles
#   Batch 29: 1000 candles
#   Batch 30: 1000 candles
#   Batch 31: 1000 candles
#   Batch 32: 1000 candles
#   Batch 33: 1000 candles
#   Batch 34: 1000 candles
#   Batch 35: 1000 candles
#   Batch 36: 1000 candles
#   Batch 37: 1000 candles
#   Batch 38: 1000 candles
#   Batch 39: 1000 candles
#   Batch 40: 1000 candles
#   Batch 41: 1000 candles
#   Batch 42: 1000 candles
#   Batch 43: 1000 candles
#   Batch 44: 1000 candles
#   Batch 45: 1000 candles
#   Batch 46: 1000 candles
#   Batch 47: 1000 candles
#   Batch 48: 1000 candles
#   Batch 49: 1000 candles
#   Batch 50: 1000 candles
#   Batch 51: 1000 candles
#   Batch 52: 1000 candles
#   Batch 53: 1000 candles
#   Batch 54: 1000 candles
#   Batch 55: 1000 candles
#   Batch 56: 1000 candles
#   Batch 57: 1000 candles
#   Batch 58: 1000 candles
#   Batch 59: 1000 candles
#   Batch 60: 1000 candles
#   Batch 61: 1000 candles
#   Batch 62: 1000 candles
#   Batch 63: 1000 candles
#   Batch 64: 1000 candles
#   Batch 65: 1000 candles
#   Batch 66: 1000 candles
#   Batch 67: 1000 candles
#   Batch 68: 1000 candles
#   Batch 69: 1000 candles
#   Batch 70: 1000 candles
#   Batch 71: 1000 candles
#   Batch 72: 1000 candles
#   Batch 73: 1000 candles
#   Batch 74: 1000 candles
#   Batch 75: 1000 candles
#   Batch 76: 1000 candles
#   Batch 77: 1000 candles
#   Batch 78: 1000 candles
#   Batch 79: 1000 candles
#   Batch 80: 1000 candles
#   Batch 81: 1000 candles
#   Batch 82: 1000 candles
#   Batch 83: 1000 candles
#   Batch 84: 1000 candles
#   Batch 85: 1000 candles
#   Batch 86: 1000 candles
#   Batch 87: 1000 candles
#   Batch 88: 1000 candles
#   Batch 89: 1000 candles
#   Batch 90: 1000 candles
#   Batch 91: 1000 candles
#   Batch 92: 1000 candles
#   Batch 93: 1000 candles
#   Batch 94: 1000 candles
#   Batch 95: 1000 candles
#   Batch 96: 1000 candles
#   Batch 97: 1000 candles
#   Batch 98: 1000 candles
#   Batch 99: 1000 candles
#   Batch 100: 1000 candles
#   Batch 101: 1000 candles
#   Batch 102: 1000 candles
#   Batch 103: 1000 candles
#   Batch 104: 1000 candles
#   Batch 105: 1000 candles
#   Batch 106: 1000 candles
#   Batch 107: 1000 candles
#   Batch 108: 1000 candles
#   Batch 109: 1000 candles
#   Batch 110: 1000 candles
#   Batch 111: 1000 candles
#   Batch 112: 1000 candles
#   Batch 113: 1000 candles
#   Batch 114: 1000 candles
#   Batch 115: 1000 candles
#   Batch 116: 1000 candles
#   Batch 117: 1000 candles
#   Batch 118: 1000 candles
#   Batch 119: 1000 candles
#   Batch 120: 1000 candles
#   Batch 121: 1000 candles
#   Batch 122: 1000 candles
#   Batch 123: 1000 candles
#   Batch 124: 1000 candles
#   Batch 125: 1000 candles
#   Batch 126: 1000 candles
#   Batch 127: 1000 candles
#   Batch 128: 1000 candles
#   Batch 129: 1000 candles
#   Batch 130: 1000 candles
#   Batch 131: 1000 candles
#   Batch 132: 1000 candles
#   Batch 133: 1000 candles
#   Batch 134: 1000 candles
#   Batch 135: 1000 candles
#   Batch 136: 1000 candles
#   Batch 137: 1000 candles
#   Batch 138: 1000 candles
#   Batch 139: 1000 candles
#   Batch 140: 1000 candles
#   Batch 141: 1000 candles
#   Batch 142: 1000 candles
#   Batch 143: 1000 candles
#   Batch 144: 1000 candles
#   Batch 145: 1000 candles
#   Batch 146: 1000 candles
#   Batch 147: 1000 candles
#   Batch 148: 1000 candles
#   Batch 149: 1000 candles
#   Batch 150: 1000 candles
#   Batch 151: 1000 candles
#   Batch 152: 1000 candles
#   Batch 153: 1000 candles
#   Batch 154: 1000 candles
#   Batch 155: 1000 candles
#   Batch 156: 1000 candles
#   Batch 157: 1000 candles
#   Batch 158: 1000 candles
#   Batch 159: 1000 candles
#   Batch 160: 1000 candles
#   Batch 161: 1000 candles
#   Batch 162: 1000 candles
#   Batch 163: 1000 candles
#   Batch 164: 1000 candles
#   Batch 165: 1000 candles
#   Batch 166: 1000 candles
#   Batch 167: 1000 candles
#   Batch 168: 1000 candles
#   Batch 169: 1000 candles
#   Batch 170: 1000 candles
#   Batch 171: 1000 candles
#   Batch 172: 1000 candles
#   Batch 173: 1000 candles
#   Batch 174: 1000 candles
#   Batch 175: 1000 candles
#   Batch 176: 1000 candles
#   Batch 177: 1000 candles
#   Batch 178: 1000 candles
#   Batch 179: 1000 candles
#   Batch 180: 1000 candles
#   Batch 181: 1000 candles
#   Batch 182: 1000 candles
#   Batch 183: 1000 candles
#   Batch 184: 1000 candles
#   Batch 185: 1000 candles
#   Batch 186: 1000 candles
#   Batch 187: 1000 candles
#   Batch 188: 1000 candles
#   Batch 189: 1000 candles
#   Batch 190: 1000 candles
#   Batch 191: 1000 candles
#   Batch 192: 1000 candles
#   Batch 193: 1000 candles
#   Batch 194: 1000 candles
#   Batch 195: 1000 candles
#   Batch 196: 1000 candles
#   Batch 197: 1000 candles
#   Batch 198: 1000 candles
#   Batch 199: 1000 candles
#   Batch 200: 1000 candles
#   Batch 201: 1000 candles
#   Batch 202: 1000 candles
#   Batch 203: 1000 candles
#   Batch 204: 1000 candles
#   Batch 205: 1000 candles
#   Batch 206: 1000 candles
#   Batch 207: 1000 candles
#   Batch 208: 1000 candles
#   Batch 209: 1000 candles
#   Batch 210: 1000 candles
#   Batch 211: 1000 candles
#   Batch 212: 1000 candles
#   Batch 213: 1000 candles
#   Batch 214: 1000 candles
#   Batch 215: 1000 candles
#   Batch 216: 1000 candles
#   Batch 217: 1000 candles
#   Batch 218: 1000 candles
#   Batch 219: 1000 candles
#   Batch 220: 1000 candles
#   Batch 221: 1000 candles
#   Batch 222: 1000 candles
#   Batch 223: 1000 candles
#   Batch 224: 1000 candles
#   Batch 225: 1000 candles
#   Batch 226: 1000 candles
#   Batch 227: 1000 candles
#   Batch 228: 1000 candles
#   Batch 229: 1000 candles
#   Batch 230: 1000 candles
#   Batch 231: 1000 candles
#   Batch 232: 1000 candles
#   Batch 233: 1000 candles
#   Batch 234: 1000 candles
#   Batch 235: 1000 candles
#   Batch 236: 1000 candles
#   Batch 237: 1000 candles
#   Batch 238: 1000 candles
#   Batch 239: 1000 candles
#   Batch 240: 1000 candles
#   Batch 241: 1000 candles
#   Batch 242: 1000 candles
#   Batch 243: 1000 candles
#   Batch 244: 1000 candles
#   Batch 245: 1000 candles
#   Batch 246: 1000 candles
#   Batch 247: 1000 candles
#   Batch 248: 1000 candles
#   Batch 249: 1000 candles
#   Batch 250: 1000 candles
#   Batch 251: 1000 candles
#   Batch 252: 1000 candles
#   Batch 253: 1000 candles
#   Batch 254: 1000 candles
#   Batch 255: 1000 candles
#   Batch 256: 1000 candles
#   Batch 257: 1000 candles
#   Batch 258: 1000 candles
#   Batch 259: 1000 candles
#   Batch 260: 1000 candles
#   Batch 261: 439 candles
#   Completed BANKUSDT: 261439 total candles
# Saved 261439 candles for BANKUSDT to /home/zac/back-testing/data/BANKUSDT_1m_candles.csv
# Saved 261439 candles for BANKUSDT to /home/zac/back-testing/data/BANKUSDT_1m_candles.csv
# Rate limit warning: 1681/2400
# Rate limit warning: 1686/2400
# Rate limit warning: 1691/2400
# Rate limit warning: 1681/2400
# Rate limit warning: 1686/2400
# Rate limit warning: 1691/2400
# Rate limit warning: 1696/2400
# Rate limit warning: 1701/2400
# Rate limit warning: 1706/2400
# Rate limit warning: 1696/2400
# Rate limit warning: 1701/2400
# Rate limit warning: 1706/2400
# Rate limit warning: 1711/2400
# Rate limit warning: 1717/2400
# Rate limit warning: 1711/2400
# Rate limit warning: 1717/2400
# Rate limit warning: 1722/2400
# Rate limit warning: 1727/2400
# Rate limit warning: 1732/2400
# Rate limit warning: 1722/2400
# Rate limit warning: 1727/2400
# Rate limit warning: 1732/2400
# Rate limit warning: 1737/2400
# Rate limit warning: 1742/2400
# Rate limit warning: 1747/2400
# Rate limit warning: 1752/2400
# Rate limit warning: 1737/2400
# Rate limit warning: 1742/2400
# Rate limit warning: 1747/2400
# Rate limit warning: 1752/2400
# Rate limit warning: 1763/2400
# Rate limit warning: 1768/2400
# Rate limit warning: 1773/2400
# Rate limit warning: 1778/2400
# Rate limit warning: 1763/2400
# Rate limit warning: 1768/2400
# Rate limit warning: 1773/2400
# Rate limit warning: 1778/2400
# Rate limit warning: 1784/2400
# Rate limit warning: 1789/2400
# Rate limit warning: 1794/2400
# Rate limit warning: 1799/2400
# Rate limit warning: 1784/2400
# Rate limit warning: 1789/2400
# Rate limit warning: 1794/2400
# Rate limit warning: 1799/2400
# Rate limit warning: 1804/2400
# Rate limit warning: 1809/2400
# Rate limit warning: 1814/2400
# Rate limit warning: 1819/2400
# Rate limit warning: 1804/2400
# Rate limit warning: 1809/2400
# Rate limit warning: 1814/2400
# Rate limit warning: 1819/2400
# Rate limit warning: 1824/2400
# Rate limit warning: 1829/2400
# Rate limit warning: 1834/2400
# Rate limit warning: 1839/2400
# Rate limit warning: 1824/2400
# Rate limit warning: 1829/2400
# Rate limit warning: 1834/2400
# Rate limit warning: 1839/2400
# Rate limit warning: 1844/2400
# Rate limit warning: 1849/2400
# Rate limit warning: 1854/2400
# Rate limit warning: 1859/2400
# Rate limit warning: 1844/2400
# Rate limit warning: 1849/2400
# Rate limit warning: 1854/2400
# Rate limit warning: 1859/2400
# Rate limit warning: 1864/2400
# Rate limit warning: 1869/2400
# Rate limit warning: 1874/2400
# Rate limit warning: 1879/2400
# Rate limit warning: 1864/2400
# Rate limit warning: 1869/2400
# Rate limit warning: 1874/2400
# Rate limit warning: 1879/2400
# Rate limit warning: 1884/2400
# Rate limit warning: 1889/2400
# Rate limit warning: 1894/2400
# Rate limit warning: 1899/2400
# Rate limit warning: 1884/2400
# Rate limit warning: 1889/2400
# Rate limit warning: 1894/2400
# Rate limit warning: 1899/2400
# Rate limit warning: 1904/2400
# Rate limit warning: 1909/2400
# Rate limit warning: 1915/2400
# Rate limit warning: 1920/2400
# Rate limit warning: 1904/2400
# Rate limit warning: 1909/2400
# Rate limit warning: 1915/2400
# Rate limit warning: 1920/2400
# Rate limit warning: 1925/2400
# Rate limit reached. Waiting 25.7 seconds...
# Rate limit warning: 1925/2400
# Rate limit reached. Waiting 25.7 seconds...
# Rate limit warning: 1930/2400
# Rate limit warning: 1935/2400
# Rate limit warning: 1940/2400
# Rate limit reached. Waiting 60.0 seconds...
# Rate limit warning: 1930/2400
# Rate limit warning: 1935/2400
# Rate limit warning: 1940/2400
# Rate limit reached. Waiting 60.0 seconds...
#   Batch 0: 1000 candles
#   Batch 1: 1000 candles
#   Batch 2: 1000 candles
#   Batch 3: 1000 candles
#   Batch 4: 1000 candles
#   Batch 5: 1000 candles
#   Batch 6: 1000 candles
#   Batch 7: 1000 candles
#   Batch 8: 1000 candles
#   Batch 9: 1000 candles
#   Batch 10: 1000 candles
#   Batch 11: 1000 candles
#   Batch 12: 1000 candles
#   Batch 13: 1000 candles
#   Batch 14: 1000 candles
#   Batch 15: 1000 candles
#   Batch 16: 1000 candles
#   Batch 17: 1000 candles
#   Batch 18: 1000 candles
#   Batch 19: 1000 candles
#   Batch 20: 1000 candles
#   Batch 21: 1000 candles
#   Batch 22: 1000 candles
#   Batch 23: 1000 candles
#   Batch 24: 1000 candles
#   Batch 25: 1000 candles
#   Batch 26: 1000 candles
#   Batch 27: 1000 candles
#   Batch 28: 1000 candles
#   Batch 29: 1000 candles
#   Batch 30: 1000 candles
#   Batch 31: 1000 candles
#   Batch 32: 1000 candles
#   Batch 33: 1000 candles
#   Batch 34: 1000 candles
#   Batch 35: 1000 candles
#   Batch 36: 1000 candles
#   Batch 37: 1000 candles
#   Batch 38: 1000 candles
#   Batch 39: 1000 candles
#   Batch 40: 1000 candles
#   Batch 41: 1000 candles
#   Batch 42: 1000 candles
#   Batch 43: 1000 candles
#   Batch 44: 1000 candles
#   Batch 45: 1000 candles
#   Batch 46: 1000 candles
#   Batch 47: 1000 candles
#   Batch 48: 1000 candles
#   Batch 49: 1000 candles
#   Batch 50: 1000 candles
#   Batch 51: 1000 candles
#   Batch 52: 1000 candles
#   Batch 53: 1000 candles
#   Batch 54: 1000 candles
#   Batch 55: 1000 candles
#   Batch 56: 1000 candles
#   Batch 57: 1000 candles
#   Batch 58: 1000 candles
#   Batch 59: 1000 candles
#   Batch 60: 1000 candles
#   Batch 61: 1000 candles
#   Batch 62: 1000 candles
#   Batch 63: 1000 candles
#   Batch 64: 1000 candles
#   Batch 65: 1000 candles
#   Batch 66: 1000 candles
#   Batch 67: 1000 candles
#   Batch 68: 1000 candles
#   Batch 69: 1000 candles
#   Batch 70: 1000 candles
#   Batch 71: 1000 candles
#   Batch 72: 1000 candles
#   Batch 73: 1000 candles
#   Batch 74: 1000 candles
#   Batch 75: 1000 candles
#   Batch 76: 1000 candles
#   Batch 77: 1000 candles
#   Batch 78: 1000 candles
#   Batch 79: 1000 candles
#   Batch 80: 1000 candles
#   Batch 81: 1000 candles
#   Batch 82: 1000 candles
#   Batch 83: 1000 candles
#   Batch 84: 1000 candles
#   Batch 85: 1000 candles
#   Batch 86: 1000 candles
#   Batch 87: 1000 candles
#   Batch 88: 1000 candles
#   Batch 89: 1000 candles
#   Batch 90: 1000 candles
#   Batch 91: 1000 candles
#   Batch 92: 1000 candles
#   Batch 93: 1000 candles
#   Batch 94: 1000 candles
#   Batch 95: 1000 candles
#   Batch 96: 1000 candles
#   Batch 97: 1000 candles
#   Batch 98: 1000 candles
#   Batch 99: 1000 candles
#   Batch 100: 1000 candles
#   Batch 101: 1000 candles
#   Batch 102: 1000 candles
#   Batch 103: 1000 candles
#   Batch 104: 1000 candles
#   Batch 105: 1000 candles
#   Batch 106: 1000 candles
#   Batch 107: 1000 candles
#   Batch 108: 1000 candles
#   Batch 109: 1000 candles
#   Batch 110: 1000 candles
#   Batch 111: 1000 candles
#   Batch 112: 1000 candles
#   Batch 113: 1000 candles
#   Batch 114: 1000 candles
#   Batch 115: 1000 candles
#   Batch 116: 1000 candles
#   Batch 117: 1000 candles
#   Batch 118: 1000 candles
#   Batch 119: 1000 candles
#   Batch 120: 1000 candles
#   Batch 121: 1000 candles
#   Batch 122: 1000 candles
#   Batch 123: 1000 candles
#   Batch 124: 1000 candles
#   Batch 125: 1000 candles
#   Batch 126: 1000 candles
#   Batch 127: 1000 candles
#   Batch 128: 1000 candles
#   Batch 129: 1000 candles
#   Batch 130: 1000 candles
#   Batch 131: 1000 candles
#   Batch 132: 1000 candles
#   Batch 133: 1000 candles
#   Batch 134: 1000 candles
#   Batch 135: 1000 candles
#   Batch 136: 1000 candles
#   Batch 137: 1000 candles
#   Batch 138: 1000 candles
#   Batch 139: 1000 candles
#   Batch 140: 1000 candles
#   Batch 141: 1000 candles
#   Batch 142: 1000 candles
#   Batch 143: 1000 candles
#   Batch 144: 1000 candles
#   Batch 145: 1000 candles
#   Batch 146: 1000 candles
#   Batch 147: 1000 candles
#   Batch 148: 1000 candles
#   Batch 149: 1000 candles
#   Batch 150: 1000 candles
#   Batch 151: 1000 candles
#   Batch 152: 1000 candles
#   Batch 153: 1000 candles
#   Batch 154: 1000 candles
#   Batch 155: 1000 candles
#   Batch 156: 1000 candles
#   Batch 157: 1000 candles
#   Batch 158: 1000 candles
#   Batch 159: 1000 candles
#   Batch 160: 1000 candles
#   Batch 161: 1000 candles
#   Batch 162: 1000 candles
#   Batch 163: 1000 candles
#   Batch 164: 1000 candles
#   Batch 165: 1000 candles
#   Batch 166: 1000 candles
#   Batch 167: 1000 candles
#   Batch 168: 1000 candles
#   Batch 169: 1000 candles
#   Batch 170: 1000 candles
#   Batch 171: 1000 candles
#   Batch 172: 1000 candles
#   Batch 173: 1000 candles
#   Batch 174: 1000 candles
#   Batch 175: 1000 candles
#   Batch 176: 1000 candles
#   Batch 177: 1000 candles
#   Batch 178: 1000 candles
#   Batch 179: 1000 candles
#   Batch 180: 1000 candles
#   Batch 181: 1000 candles
#   Batch 182: 1000 candles
#   Batch 183: 1000 candles
#   Batch 184: 1000 candles
#   Batch 185: 1000 candles
#   Batch 186: 1000 candles
#   Batch 187: 1000 candles
#   Batch 188: 1000 candles
#   Batch 189: 1000 candles
#   Batch 190: 1000 candles
#   Batch 191: 1000 candles
#   Batch 192: 1000 candles
#   Batch 193: 1000 candles
#   Batch 194: 1000 candles
#   Batch 195: 1000 candles
#   Batch 196: 1000 candles
#   Batch 197: 1000 candles
#   Batch 198: 1000 candles
#   Batch 199: 1000 candles
#   Batch 200: 1000 candles
#   Batch 201: 1000 candles
#   Batch 202: 1000 candles
#   Batch 203: 1000 candles
#   Batch 204: 1000 candles
#   Batch 205: 1000 candles
#   Batch 206: 1000 candles
#   Batch 207: 1000 candles
#   Batch 208: 1000 candles
#   Batch 209: 1000 candles
#   Batch 210: 1000 candles
#   Batch 211: 1000 candles
#   Batch 212: 1000 candles
#   Batch 213: 1000 candles
#   Batch 214: 1000 candles
#   Batch 215: 1000 candles
#   Batch 216: 1000 candles
#   Batch 217: 1000 candles
#   Batch 218: 1000 candles
#   Batch 219: 1000 candles
#   Batch 220: 1000 candles
#   Batch 221: 1000 candles
#   Batch 222: 1000 candles
#   Batch 223: 1000 candles
#   Batch 224: 1000 candles
#   Batch 225: 1000 candles
#   Batch 226: 1000 candles
#   Batch 227: 1000 candles
#   Batch 228: 1000 candles
#   Batch 229: 1000 candles
#   Batch 230: 1000 candles
#   Batch 231: 1000 candles
#   Batch 232: 1000 candles
#   Batch 233: 1000 candles
#   Batch 234: 1000 candles
#   Batch 235: 1000 candles
#   Batch 236: 1000 candles
#   Batch 237: 1000 candles
#   Batch 238: 1000 candles
#   Batch 239: 1000 candles
#   Batch 240: 1000 candles
#   Batch 241: 1000 candles
#   Batch 242: 1000 candles
#   Batch 243: 1000 candles
#   Batch 244: 1000 candles
#   Batch 245: 1000 candles
#   Batch 246: 1000 candles
#   Batch 247: 1000 candles
#   Batch 248: 1000 candles
#   Batch 249: 1000 candles
#   Batch 250: 1000 candles
#   Batch 251: 1000 candles
#   Batch 252: 1000 candles
#   Batch 253: 1000 candles
#   Batch 254: 1000 candles
#   Batch 255: 1000 candles
#   Batch 256: 1000 candles
#   Batch 257: 1000 candles
#   Batch 258: 1000 candles
#   Batch 259: 1000 candles
#   Batch 260: 1000 candles
#   Batch 261: 1000 candles
#   Batch 262: 1000 candles
#   Batch 263: 1000 candles
#   Batch 264: 1000 candles
#   Batch 265: 1000 candles
#   Batch 266: 1000 candles
#   Batch 267: 1000 candles
#   Batch 268: 1000 candles
#   Batch 269: 1000 candles
#   Batch 270: 1000 candles
#   Batch 271: 1000 candles
#   Batch 272: 1000 candles
#   Batch 273: 1000 candles
#   Batch 274: 1000 candles
#   Batch 275: 1000 candles
#   Batch 276: 1000 candles
#   Batch 277: 1000 candles
#   Batch 278: 1000 candles
#   Batch 279: 1000 candles
#   Batch 280: 1000 candles
#   Batch 281: 1000 candles
#   Batch 282: 1000 candles
#   Batch 283: 1000 candles
#   Batch 284: 1000 candles
#   Batch 285: 1000 candles
#   Batch 286: 1000 candles
#   Batch 287: 1000 candles
#   Batch 288: 1000 candles
#   Batch 289: 1000 candles
#   Batch 290: 1000 candles
#   Batch 291: 1000 candles
#   Batch 292: 1000 candles
#   Batch 293: 1000 candles
#   Batch 294: 1000 candles
#   Batch 295: 1000 candles
#   Batch 296: 1000 candles
#   Batch 297: 1000 candles
#   Batch 298: 1000 candles
#   Batch 299: 1000 candles
#   Batch 300: 1000 candles
#   Batch 301: 1000 candles
#   Batch 302: 1000 candles
#   Batch 303: 1000 candles
#   Batch 304: 1000 candles
#   Batch 305: 1000 candles
#   Batch 306: 1000 candles
#   Batch 307: 1000 candles
#   Batch 308: 1000 candles
#   Batch 309: 1000 candles
#   Batch 310: 1000 candles
#   Batch 311: 1000 candles
#   Batch 312: 1000 candles
#   Batch 313: 1000 candles
#   Batch 314: 1000 candles
#   Batch 315: 1000 candles
#   Batch 316: 1000 candles
#   Batch 317: 1000 candles
#   Batch 318: 1000 candles
#   Batch 319: 1000 candles
#   Batch 320: 1000 candles
#   Batch 321: 1000 candles
#   Batch 322: 1000 candles
#   Batch 323: 1000 candles
#   Batch 324: 1000 candles
#   Batch 325: 1000 candles
#   Batch 326: 1000 candles
#   Batch 327: 1000 candles
#   Batch 328: 1000 candles
#   Batch 329: 1000 candles
#   Batch 330: 1000 candles
#   Batch 331: 1000 candles
#   Batch 332: 1000 candles
#   Batch 333: 1000 candles
#   Batch 334: 1000 candles
#   Batch 335: 1000 candles
#   Batch 336: 1000 candles
#   Batch 337: 1000 candles
#   Batch 338: 1000 candles
#   Batch 339: 1000 candles
#   Batch 340: 1000 candles
#   Batch 341: 1000 candles
#   Batch 342: 1000 candles
#   Batch 343: 1000 candles
#   Batch 344: 1000 candles
#   Batch 345: 1000 candles
#   Batch 346: 1000 candles
#   Batch 347: 1000 candles
#   Batch 348: 1000 candles
#   Batch 349: 1000 candles
#   Batch 350: 1000 candles
#   Batch 351: 1000 candles
#   Batch 352: 1000 candles
#   Batch 353: 1000 candles
#   Batch 354: 1000 candles
#   Batch 355: 1000 candles
#   Batch 356: 1000 candles
#   Batch 357: 1000 candles
#   Batch 358: 1000 candles
#   Batch 359: 1000 candles
#   Batch 360: 1000 candles
#   Batch 361: 1000 candles
#   Batch 362: 1000 candles
#   Batch 363: 1000 candles
#   Batch 364: 1000 candles
#   Batch 365: 1000 candles
#   Batch 366: 1000 candles
#   Batch 367: 1000 candles
#   Batch 368: 1000 candles
#   Batch 369: 1000 candles
#   Batch 370: 1000 candles
#   Batch 371: 1000 candles
#   Batch 372: 1000 candles
#   Batch 373: 1000 candles
#   Batch 374: 1000 candles
#   Batch 375: 1000 candles
#   Batch 376: 1000 candles
#   Batch 377: 1000 candles
#   Batch 378: 1000 candles
#   Batch 379: 1000 candles
#   Batch 380: 1000 candles
#   Batch 381: 1000 candles
#   Batch 382: 1000 candles
#   Batch 383: 1000 candles
#   Batch 384: 1000 candles
#   Batch 385: 1000 candles
#   Batch 386: 1000 candles
#   Batch 387: 1000 candles
#   Batch 388: 1000 candles
#   Batch 389: 1000 candles
#   Batch 390: 1000 candles
#   Batch 391: 1000 candles
#   Batch 392: 1000 candles
#   Batch 393: 1000 candles
#   Batch 394: 1000 candles
#   Batch 395: 1000 candles
#   Batch 396: 1000 candles
#   Batch 397: 1000 candles
#   Batch 398: 1000 candles
#   Batch 399: 1000 candles
#   Batch 400: 1000 candles
#   Batch 401: 1000 candles
#   Batch 402: 1000 candles
#   Batch 403: 1000 candles
#   Batch 404: 1000 candles
#   Batch 405: 1000 candles
#   Batch 406: 1000 candles
#   Batch 407: 1000 candles
#   Batch 408: 1000 candles
#   Batch 409: 1000 candles
#   Batch 410: 1000 candles
#   Batch 411: 1000 candles
#   Batch 412: 1000 candles
#   Batch 413: 1000 candles
#   Batch 414: 1000 candles
#   Batch 415: 1000 candles
#   Batch 416: 1000 candles
#   Batch 417: 1000 candles
#   Batch 418: 1000 candles
#   Batch 419: 1000 candles
#   Batch 420: 1000 candles
#   Batch 421: 1000 candles
#   Batch 422: 1000 candles
#   Batch 423: 1000 candles
#   Batch 424: 1000 candles
#   Batch 425: 1000 candles
#   Batch 426: 1000 candles
#   Batch 427: 1000 candles
#   Batch 428: 1000 candles
#   Batch 429: 1000 candles
#   Batch 430: 1000 candles
#   Batch 431: 1000 candles
#   Batch 432: 1000 candles
#   Batch 433: 1000 candles
#   Batch 434: 1000 candles
#   Batch 435: 1000 candles
#   Batch 436: 1000 candles
#   Batch 437: 1000 candles
#   Batch 438: 1000 candles
#   Batch 439: 1000 candles
#   Batch 440: 1000 candles
#   Batch 441: 1000 candles
#   Batch 442: 1000 candles
#   Batch 443: 1000 candles
#   Batch 444: 1000 candles
#   Batch 445: 1000 candles
#   Batch 446: 1000 candles
#   Batch 447: 1000 candles
#   Batch 448: 1000 candles
#   Batch 449: 1000 candles
#   Batch 450: 1000 candles
#   Batch 451: 1000 candles
#   Batch 452: 1000 candles
#   Batch 453: 1000 candles
#   Batch 454: 1000 candles
#   Batch 455: 1000 candles
#   Batch 456: 1000 candles
#   Batch 457: 1000 candles
#   Batch 458: 1000 candles
#   Batch 459: 1000 candles
#   Batch 460: 1000 candles
#   Batch 461: 1000 candles
#   Batch 462: 1000 candles
#   Batch 463: 1000 candles
#   Batch 464: 1000 candles
#   Batch 465: 1000 candles
#   Batch 466: 1000 candles
#   Batch 467: 1000 candles
#   Batch 468: 1000 candles
#   Batch 469: 1000 candles
#   Batch 470: 1000 candles
#   Batch 471: 1000 candles
#   Batch 472: 1000 candles
#   Batch 473: 1000 candles
#   Batch 474: 1000 candles
#   Batch 475: 1000 candles
#   Batch 476: 1000 candles
#   Batch 477: 1000 candles
#   Batch 478: 1000 candles
#   Batch 479: 1000 candles
#   Batch 480: 1000 candles
#   Batch 481: 1000 candles
#   Batch 482: 1000 candles
#   Batch 483: 1000 candles
#   Batch 484: 1000 candles
#   Batch 485: 1000 candles
#   Batch 486: 1000 candles
#   Batch 487: 1000 candles
#   Batch 488: 1000 candles
#   Batch 489: 1000 candles
#   Batch 490: 1000 candles
#   Batch 491: 1000 candles
#   Batch 492: 1000 candles
#   Batch 493: 1000 candles
#   Batch 494: 1000 candles
#   Batch 495: 1000 candles
#   Batch 496: 1000 candles
#   Batch 497: 1000 candles
#   Batch 498: 1000 candles
#   Batch 499: 1000 candles
#   Batch 500: 1000 candles
#   Batch 501: 1000 candles
#   Batch 502: 1000 candles
#   Batch 503: 1000 candles
#   Batch 504: 1000 candles
#   Batch 505: 1000 candles
#   Batch 506: 1000 candles
#   Batch 507: 1000 candles
#   Batch 508: 1000 candles
#   Batch 509: 1000 candles
#   Batch 510: 1000 candles
#   Batch 511: 1000 candles
#   Batch 512: 1000 candles
#   Batch 513: 1000 candles
#   Batch 514: 1000 candles
#   Batch 515: 1000 candles
#   Batch 516: 1000 candles
#   Batch 517: 1000 candles
#   Batch 518: 1000 candles
#   Batch 519: 1000 candles
#   Batch 520: 1000 candles
#   Batch 521: 1000 candles
#   Batch 522: 1000 candles
#   Batch 523: 1000 candles
#   Batch 524: 160 candles
#   Completed RLCUSDT: 524160 total candles
#   Batch 0: 1000 candles
#   Batch 1: 1000 candles
#   Batch 2: 1000 candles
#   Batch 3: 1000 candles
#   Batch 4: 1000 candles
#   Batch 5: 1000 candles
#   Batch 6: 1000 candles
#   Batch 7: 1000 candles
#   Batch 8: 1000 candles
#   Batch 9: 1000 candles
#   Batch 10: 1000 candles
#   Batch 11: 1000 candles
#   Batch 12: 1000 candles
#   Batch 13: 1000 candles
#   Batch 14: 1000 candles
#   Batch 15: 1000 candles
#   Batch 16: 1000 candles
#   Batch 17: 1000 candles
#   Batch 18: 1000 candles
#   Batch 19: 1000 candles
#   Batch 20: 1000 candles
#   Batch 21: 1000 candles
#   Batch 22: 1000 candles
#   Batch 23: 1000 candles
#   Batch 24: 1000 candles
#   Batch 25: 1000 candles
#   Batch 26: 1000 candles
#   Batch 27: 1000 candles
#   Batch 28: 1000 candles
#   Batch 29: 1000 candles
#   Batch 30: 1000 candles
#   Batch 31: 1000 candles
#   Batch 32: 1000 candles
#   Batch 33: 1000 candles
#   Batch 34: 1000 candles
#   Batch 35: 1000 candles
#   Batch 36: 1000 candles
#   Batch 37: 1000 candles
#   Batch 38: 1000 candles
#   Batch 39: 1000 candles
#   Batch 40: 1000 candles
#   Batch 41: 1000 candles
#   Batch 42: 1000 candles
#   Batch 43: 1000 candles
#   Batch 44: 1000 candles
#   Batch 45: 1000 candles
#   Batch 46: 1000 candles
#   Batch 47: 1000 candles
#   Batch 48: 1000 candles
#   Batch 49: 1000 candles
#   Batch 50: 1000 candles
#   Batch 51: 1000 candles
#   Batch 52: 1000 candles
#   Batch 53: 1000 candles
#   Batch 54: 1000 candles
#   Batch 55: 1000 candles
#   Batch 56: 1000 candles
#   Batch 57: 1000 candles
#   Batch 58: 1000 candles
#   Batch 59: 1000 candles
#   Batch 60: 1000 candles
#   Batch 61: 1000 candles
#   Batch 62: 1000 candles
#   Batch 63: 1000 candles
#   Batch 64: 1000 candles
#   Batch 65: 1000 candles
#   Batch 66: 1000 candles
#   Batch 67: 1000 candles
#   Batch 68: 1000 candles
#   Batch 69: 1000 candles
#   Batch 70: 1000 candles
#   Batch 71: 1000 candles
#   Batch 72: 1000 candles
#   Batch 73: 1000 candles
#   Batch 74: 1000 candles
#   Batch 75: 1000 candles
#   Batch 76: 1000 candles
#   Batch 77: 1000 candles
#   Batch 78: 1000 candles
#   Batch 79: 1000 candles
#   Batch 80: 1000 candles
#   Batch 81: 1000 candles
#   Batch 82: 1000 candles
#   Batch 83: 1000 candles
#   Batch 84: 1000 candles
#   Batch 85: 1000 candles
#   Batch 86: 1000 candles
#   Batch 87: 1000 candles
#   Batch 88: 1000 candles
#   Batch 89: 1000 candles
#   Batch 90: 1000 candles
#   Batch 91: 1000 candles
#   Batch 92: 1000 candles
#   Batch 93: 1000 candles
#   Batch 94: 1000 candles
#   Batch 95: 1000 candles
#   Batch 96: 1000 candles
#   Batch 97: 1000 candles
#   Batch 98: 1000 candles
#   Batch 99: 1000 candles
#   Batch 100: 1000 candles
#   Batch 101: 1000 candles
#   Batch 102: 1000 candles
#   Batch 103: 1000 candles
#   Batch 104: 1000 candles
#   Batch 105: 1000 candles
#   Batch 106: 1000 candles
#   Batch 107: 1000 candles
#   Batch 108: 1000 candles
#   Batch 109: 1000 candles
#   Batch 110: 1000 candles
#   Batch 111: 1000 candles
#   Batch 112: 1000 candles
#   Batch 113: 1000 candles
#   Batch 114: 1000 candles
#   Batch 115: 1000 candles
#   Batch 116: 1000 candles
#   Batch 117: 1000 candles
#   Batch 118: 1000 candles
#   Batch 119: 1000 candles
#   Batch 120: 1000 candles
#   Batch 121: 1000 candles
#   Batch 122: 1000 candles
#   Batch 123: 1000 candles
#   Batch 124: 1000 candles
#   Batch 125: 1000 candles
#   Batch 126: 1000 candles
#   Batch 127: 1000 candles
#   Batch 128: 1000 candles
#   Batch 129: 1000 candles
#   Batch 130: 1000 candles
#   Batch 131: 1000 candles
#   Batch 132: 1000 candles
#   Batch 133: 1000 candles
#   Batch 134: 1000 candles
#   Batch 135: 1000 candles
#   Batch 136: 1000 candles
#   Batch 137: 1000 candles
#   Batch 138: 1000 candles
#   Batch 139: 1000 candles
#   Batch 140: 1000 candles
#   Batch 141: 1000 candles
#   Batch 142: 1000 candles
#   Batch 143: 1000 candles
#   Batch 144: 1000 candles
#   Batch 145: 1000 candles
#   Batch 146: 1000 candles
#   Batch 147: 1000 candles
#   Batch 148: 1000 candles
#   Batch 149: 1000 candles
#   Batch 150: 1000 candles
#   Batch 151: 1000 candles
#   Batch 152: 1000 candles
#   Batch 153: 1000 candles
#   Batch 154: 1000 candles
#   Batch 155: 1000 candles
#   Batch 156: 1000 candles
#   Batch 157: 1000 candles
#   Batch 158: 1000 candles
#   Batch 159: 1000 candles
#   Batch 160: 1000 candles
#   Batch 161: 1000 candles
#   Batch 162: 1000 candles
#   Batch 163: 1000 candles
#   Batch 164: 1000 candles
#   Batch 165: 1000 candles
#   Batch 166: 1000 candles
#   Batch 167: 1000 candles
#   Batch 168: 1000 candles
#   Batch 169: 1000 candles
#   Batch 170: 1000 candles
#   Batch 171: 1000 candles
#   Batch 172: 1000 candles
#   Batch 173: 1000 candles
#   Batch 174: 1000 candles
#   Batch 175: 1000 candles
#   Batch 176: 1000 candles
#   Batch 177: 1000 candles
#   Batch 178: 1000 candles
#   Batch 179: 1000 candles
#   Batch 180: 1000 candles
#   Batch 181: 1000 candles
#   Batch 182: 1000 candles
#   Batch 183: 1000 candles
#   Batch 184: 1000 candles
#   Batch 185: 1000 candles
#   Batch 186: 1000 candles
#   Batch 187: 1000 candles
#   Batch 188: 1000 candles
#   Batch 189: 1000 candles
#   Batch 190: 1000 candles
#   Batch 191: 1000 candles
#   Batch 192: 1000 candles
#   Batch 193: 1000 candles
#   Batch 194: 1000 candles
#   Batch 195: 1000 candles
#   Batch 196: 1000 candles
#   Batch 197: 1000 candles
#   Batch 198: 1000 candles
#   Batch 199: 1000 candles
#   Batch 200: 1000 candles
#   Batch 201: 1000 candles
#   Batch 202: 1000 candles
#   Batch 203: 1000 candles
#   Batch 204: 1000 candles
#   Batch 205: 1000 candles
#   Batch 206: 1000 candles
#   Batch 207: 1000 candles
#   Batch 208: 1000 candles
#   Batch 209: 1000 candles
#   Batch 210: 1000 candles
#   Batch 211: 1000 candles
#   Batch 212: 1000 candles
#   Batch 213: 1000 candles
#   Batch 214: 1000 candles
#   Batch 215: 1000 candles
#   Batch 216: 1000 candles
#   Batch 217: 1000 candles
#   Batch 218: 1000 candles
#   Batch 219: 1000 candles
#   Batch 220: 1000 candles
#   Batch 221: 1000 candles
#   Batch 222: 1000 candles
#   Batch 223: 1000 candles
#   Batch 224: 1000 candles
#   Batch 225: 1000 candles
#   Batch 226: 1000 candles
#   Batch 227: 1000 candles
#   Batch 228: 1000 candles
#   Batch 229: 1000 candles
#   Batch 230: 1000 candles
#   Batch 231: 1000 candles
#   Batch 232: 1000 candles
#   Batch 233: 1000 candles
#   Batch 234: 1000 candles
#   Batch 235: 1000 candles
#   Batch 236: 1000 candles
#   Batch 237: 1000 candles
#   Batch 238: 1000 candles
#   Batch 239: 1000 candles
#   Batch 240: 1000 candles
#   Batch 241: 1000 candles
#   Batch 242: 1000 candles
#   Batch 243: 1000 candles
#   Batch 244: 1000 candles
#   Batch 245: 1000 candles
#   Batch 246: 1000 candles
#   Batch 247: 1000 candles
#   Batch 248: 1000 candles
#   Batch 249: 1000 candles
#   Batch 250: 1000 candles
#   Batch 251: 1000 candles
#   Batch 252: 1000 candles
#   Batch 253: 1000 candles
#   Batch 254: 1000 candles
#   Batch 255: 1000 candles
#   Batch 256: 1000 candles
#   Batch 257: 1000 candles
#   Batch 258: 1000 candles
#   Batch 259: 1000 candles
#   Batch 260: 1000 candles
#   Batch 261: 1000 candles
#   Batch 262: 1000 candles
#   Batch 263: 1000 candles
#   Batch 264: 1000 candles
#   Batch 265: 1000 candles
#   Batch 266: 1000 candles
#   Batch 267: 1000 candles
#   Batch 268: 1000 candles
#   Batch 269: 1000 candles
#   Batch 270: 1000 candles
#   Batch 271: 1000 candles
#   Batch 272: 1000 candles
#   Batch 273: 1000 candles
#   Batch 274: 1000 candles
#   Batch 275: 1000 candles
#   Batch 276: 1000 candles
#   Batch 277: 1000 candles
#   Batch 278: 1000 candles
#   Batch 279: 1000 candles
#   Batch 280: 1000 candles
#   Batch 281: 1000 candles
#   Batch 282: 1000 candles
#   Batch 283: 1000 candles
#   Batch 284: 1000 candles
#   Batch 285: 1000 candles
#   Batch 286: 1000 candles
#   Batch 287: 1000 candles
#   Batch 288: 1000 candles
#   Batch 289: 1000 candles
#   Batch 290: 1000 candles
#   Batch 291: 1000 candles
#   Batch 292: 1000 candles
#   Batch 293: 1000 candles
#   Batch 294: 1000 candles
#   Batch 295: 1000 candles
#   Batch 296: 1000 candles
#   Batch 297: 1000 candles
#   Batch 298: 1000 candles
#   Batch 299: 1000 candles
#   Batch 300: 1000 candles
#   Batch 301: 1000 candles
#   Batch 302: 1000 candles
#   Batch 303: 1000 candles
#   Batch 304: 1000 candles
#   Batch 305: 1000 candles
#   Batch 306: 1000 candles
#   Batch 307: 1000 candles
#   Batch 308: 1000 candles
#   Batch 309: 1000 candles
#   Batch 310: 1000 candles
#   Batch 311: 1000 candles
#   Batch 312: 1000 candles
#   Batch 313: 1000 candles
#   Batch 314: 1000 candles
#   Batch 315: 1000 candles
#   Batch 316: 1000 candles
#   Batch 317: 1000 candles
#   Batch 318: 1000 candles
#   Batch 319: 1000 candles
#   Batch 320: 1000 candles
#   Batch 321: 1000 candles
#   Batch 322: 1000 candles
#   Batch 323: 1000 candles
#   Batch 324: 1000 candles
#   Batch 325: 1000 candles
#   Batch 326: 1000 candles
#   Batch 327: 1000 candles
#   Batch 328: 1000 candles
#   Batch 329: 1000 candles
#   Batch 330: 1000 candles
#   Batch 331: 1000 candles
#   Batch 332: 1000 candles
#   Batch 333: 1000 candles
#   Batch 334: 1000 candles
#   Batch 335: 1000 candles
#   Batch 336: 1000 candles
#   Batch 337: 1000 candles
#   Batch 338: 1000 candles
#   Batch 339: 1000 candles
#   Batch 340: 1000 candles
#   Batch 341: 1000 candles
#   Batch 342: 1000 candles
#   Batch 343: 1000 candles
#   Batch 344: 1000 candles
#   Batch 345: 1000 candles
#   Batch 346: 1000 candles
#   Batch 347: 1000 candles
#   Batch 348: 1000 candles
#   Batch 349: 1000 candles
#   Batch 350: 1000 candles
#   Batch 351: 1000 candles
#   Batch 352: 1000 candles
#   Batch 353: 1000 candles
#   Batch 354: 1000 candles
#   Batch 355: 1000 candles
#   Batch 356: 1000 candles
#   Batch 357: 1000 candles
#   Batch 358: 1000 candles
#   Batch 359: 1000 candles
#   Batch 360: 1000 candles
#   Batch 361: 1000 candles
#   Batch 362: 1000 candles
#   Batch 363: 1000 candles
#   Batch 364: 1000 candles
#   Batch 365: 1000 candles
#   Batch 366: 1000 candles
#   Batch 367: 1000 candles
#   Batch 368: 1000 candles
#   Batch 369: 1000 candles
#   Batch 370: 1000 candles
#   Batch 371: 1000 candles
#   Batch 372: 1000 candles
#   Batch 373: 1000 candles
#   Batch 374: 1000 candles
#   Batch 375: 1000 candles
#   Batch 376: 1000 candles
#   Batch 377: 1000 candles
#   Batch 378: 1000 candles
#   Batch 379: 1000 candles
#   Batch 380: 1000 candles
#   Batch 381: 1000 candles
#   Batch 382: 1000 candles
#   Batch 383: 1000 candles
#   Batch 384: 1000 candles
#   Batch 385: 1000 candles
#   Batch 386: 1000 candles
#   Batch 387: 1000 candles
#   Batch 388: 1000 candles
#   Batch 389: 1000 candles
#   Batch 390: 1000 candles
#   Batch 391: 1000 candles
#   Batch 392: 1000 candles
#   Batch 393: 1000 candles
#   Batch 394: 1000 candles
#   Batch 395: 1000 candles
#   Batch 396: 1000 candles
#   Batch 397: 1000 candles
#   Batch 398: 1000 candles
#   Batch 399: 1000 candles
#   Batch 400: 1000 candles
#   Batch 401: 1000 candles
#   Batch 402: 1000 candles
#   Batch 403: 1000 candles
#   Batch 404: 1000 candles
#   Batch 405: 1000 candles
#   Batch 406: 1000 candles
#   Batch 407: 1000 candles
#   Batch 408: 1000 candles
#   Batch 409: 1000 candles
#   Batch 410: 1000 candles
#   Batch 411: 1000 candles
#   Batch 412: 1000 candles
#   Batch 413: 1000 candles
#   Batch 414: 1000 candles
#   Batch 415: 1000 candles
#   Batch 416: 1000 candles
#   Batch 417: 1000 candles
#   Batch 418: 1000 candles
#   Batch 419: 1000 candles
#   Batch 420: 1000 candles
#   Batch 421: 1000 candles
#   Batch 422: 1000 candles
#   Batch 423: 1000 candles
#   Batch 424: 1000 candles
#   Batch 425: 1000 candles
#   Batch 426: 1000 candles
#   Batch 427: 1000 candles
#   Batch 428: 1000 candles
#   Batch 429: 1000 candles
#   Batch 430: 1000 candles
#   Batch 431: 1000 candles
#   Batch 432: 1000 candles
#   Batch 433: 1000 candles
#   Batch 434: 1000 candles
#   Batch 435: 1000 candles
#   Batch 436: 1000 candles
#   Batch 437: 1000 candles
#   Batch 438: 1000 candles
#   Batch 439: 1000 candles
#   Batch 440: 1000 candles
#   Batch 441: 1000 candles
#   Batch 442: 1000 candles
#   Batch 443: 1000 candles
#   Batch 444: 1000 candles
#   Batch 445: 1000 candles
#   Batch 446: 1000 candles
#   Batch 447: 1000 candles
#   Batch 448: 1000 candles
#   Batch 449: 1000 candles
#   Batch 450: 1000 candles
#   Batch 451: 1000 candles
#   Batch 452: 1000 candles
#   Batch 453: 1000 candles
#   Batch 454: 1000 candles
#   Batch 455: 1000 candles
#   Batch 456: 1000 candles
#   Batch 457: 1000 candles
#   Batch 458: 1000 candles
#   Batch 459: 1000 candles
#   Batch 460: 1000 candles
#   Batch 461: 1000 candles
#   Batch 462: 1000 candles
#   Batch 463: 1000 candles
#   Batch 464: 1000 candles
#   Batch 465: 1000 candles
#   Batch 466: 1000 candles
#   Batch 467: 1000 candles
#   Batch 468: 1000 candles
#   Batch 469: 1000 candles
#   Batch 470: 1000 candles
#   Batch 471: 1000 candles
#   Batch 472: 1000 candles
#   Batch 473: 1000 candles
#   Batch 474: 1000 candles
#   Batch 475: 1000 candles
#   Batch 476: 1000 candles
#   Batch 477: 1000 candles
#   Batch 478: 1000 candles
#   Batch 479: 1000 candles
#   Batch 480: 1000 candles
#   Batch 481: 1000 candles
#   Batch 482: 1000 candles
#   Batch 483: 1000 candles
#   Batch 484: 1000 candles
#   Batch 485: 1000 candles
#   Batch 486: 1000 candles
#   Batch 487: 1000 candles
#   Batch 488: 1000 candles
#   Batch 489: 1000 candles
#   Batch 490: 1000 candles
#   Batch 491: 1000 candles
#   Batch 492: 1000 candles
#   Batch 493: 1000 candles
#   Batch 494: 1000 candles
#   Batch 495: 1000 candles
#   Batch 496: 1000 candles
#   Batch 497: 1000 candles
#   Batch 498: 1000 candles
#   Batch 499: 1000 candles
#   Batch 500: 1000 candles
#   Batch 501: 1000 candles
#   Batch 502: 1000 candles
#   Batch 503: 1000 candles
#   Batch 504: 1000 candles
#   Batch 505: 1000 candles
#   Batch 506: 1000 candles
#   Batch 507: 1000 candles
#   Batch 508: 1000 candles
#   Batch 509: 1000 candles
#   Batch 510: 1000 candles
#   Batch 511: 1000 candles
#   Batch 512: 1000 candles
#   Batch 513: 1000 candles
#   Batch 514: 1000 candles
#   Batch 515: 1000 candles
#   Batch 516: 1000 candles
#   Batch 517: 1000 candles
#   Batch 518: 1000 candles
#   Batch 519: 1000 candles
#   Batch 520: 1000 candles
# ...
#   Batch 459: 1000 candles
#   Batch 460: 1000 candles
#   Batch 461: 1000 candles
#   Batch 462: 1000 candles
#   Batch 463: 1000 candles
#   Batch 464: 1000 candles
#   Batch 465: 1000 candles
#   Batch 466: 1000 candles
#   Batch 467: 1000 candles
#   Batch 468: 1000 candles
#   Batch 469: 1000 candles
#   Batch 470: 1000 candles
#   Batch 471: 1000 candles
#   Batch 472: 1000 candles
#   Batch 473: 1000 candles
#   Batch 474: 1000 candles
#   Batch 475: 1000 candles
#   Batch 476: 1000 candles
#   Batch 477: 1000 candles
#   Batch 478: 1000 candles
#   Batch 479: 1000 candles
#   Batch 480: 1000 candles
#   Batch 481: 1000 candles
#   Batch 482: 1000 candles
#   Batch 483: 1000 candles
#   Batch 484: 1000 candles
#   Batch 485: 1000 candles
#   Batch 486: 1000 candles
#   Batch 487: 1000 candles
#   Batch 488: 1000 candles
#   Batch 489: 1000 candles
#   Batch 490: 1000 candles
#   Batch 491: 1000 candles
#   Batch 492: 1000 candles
#   Batch 493: 1000 candles
#   Batch 494: 1000 candles
#   Batch 495: 1000 candles
#   Batch 496: 1000 candles
#   Batch 497: 1000 candles
#   Batch 498: 1000 candles
#   Batch 499: 1000 candles
#   Batch 500: 1000 candles
#   Batch 501: 1000 candles
#   Batch 502: 1000 candles
#   Batch 503: 1000 candles
#   Batch 504: 1000 candles
#   Batch 505: 1000 candles
#   Batch 506: 1000 candles
#   Batch 507: 1000 candles
#   Batch 508: 1000 candles
#   Batch 509: 1000 candles
#   Batch 510: 1000 candles
#   Batch 511: 1000 candles
#   Batch 512: 1000 candles
#   Batch 513: 1000 candles
#   Batch 514: 1000 candles
#   Batch 515: 1000 candles
#   Batch 516: 1000 candles
#   Batch 517: 1000 candles
#   Batch 518: 1000 candles
#   Batch 519: 1000 candles
#   Batch 520: 1000 candles
#   Batch 521: 1000 candles
#   Batch 522: 1000 candles
#   Batch 523: 1000 candles
#   Batch 524: 160 candles
#   Completed METISUSDT: 524160 total candles
#   Batch 0: 1000 candles
#   Batch 1: 1000 candles
#   Batch 2: 1000 candles
#   Batch 3: 1000 candles
#   Batch 4: 1000 candles
#   Batch 5: 1000 candles
#   Batch 6: 1000 candles
#   Batch 7: 1000 candles
#   Batch 8: 1000 candles
#   Batch 9: 1000 candles
#   Batch 10: 1000 candles
#   Batch 11: 1000 candles
#   Batch 12: 1000 candles
#   Batch 13: 1000 candles
#   Batch 14: 1000 candles
#   Batch 15: 1000 candles
#   Batch 16: 1000 candles
#   Batch 17: 1000 candles
#   Batch 18: 1000 candles
#   Batch 19: 1000 candles
#   Batch 20: 1000 candles
#   Batch 21: 1000 candles
#   Batch 22: 1000 candles
#   Batch 23: 1000 candles
#   Batch 24: 1000 candles
#   Batch 25: 1000 candles
#   Batch 26: 1000 candles
#   Batch 27: 1000 candles
#   Batch 28: 1000 candles
#   Batch 29: 1000 candles
#   Batch 30: 1000 candles
#   Batch 31: 1000 candles
#   Batch 32: 1000 candles
#   Batch 33: 1000 candles
#   Batch 34: 1000 candles
#   Batch 35: 1000 candles
#   Batch 36: 1000 candles
#   Batch 37: 1000 candles
#   Batch 38: 1000 candles
#   Batch 39: 1000 candles
#   Batch 40: 1000 candles
#   Batch 41: 1000 candles
#   Batch 42: 1000 candles
#   Batch 43: 1000 candles
#   Batch 44: 1000 candles
#   Batch 45: 1000 candles
#   Batch 46: 1000 candles
#   Batch 47: 1000 candles
#   Batch 48: 1000 candles
#   Batch 49: 1000 candles
#   Batch 50: 1000 candles
#   Batch 51: 1000 candles
#   Batch 52: 1000 candles
#   Batch 53: 1000 candles
#   Batch 54: 1000 candles
#   Batch 55: 1000 candles
#   Batch 56: 1000 candles
#   Batch 57: 1000 candles
#   Batch 58: 1000 candles
#   Batch 59: 1000 candles
#   Batch 60: 1000 candles
#   Batch 61: 1000 candles
#   Batch 62: 1000 candles
#   Batch 63: 1000 candles
#   Batch 64: 1000 candles
#   Batch 65: 1000 candles
#   Batch 66: 1000 candles
#   Batch 67: 1000 candles
#   Batch 68: 1000 candles
#   Batch 69: 1000 candles
#   Batch 70: 1000 candles
#   Batch 71: 1000 candles
#   Batch 72: 1000 candles
#   Batch 73: 1000 candles
#   Batch 74: 1000 candles
#   Batch 75: 1000 candles
#   Batch 76: 1000 candles
#   Batch 77: 1000 candles
#   Batch 78: 1000 candles
#   Batch 79: 1000 candles
#   Batch 80: 1000 candles
#   Batch 81: 1000 candles
#   Batch 82: 1000 candles
#   Batch 83: 1000 candles
#   Batch 84: 1000 candles
#   Batch 85: 1000 candles
#   Batch 86: 1000 candles
#   Batch 87: 1000 candles
#   Batch 88: 1000 candles
#   Batch 89: 1000 candles
#   Batch 90: 1000 candles
#   Batch 91: 1000 candles
#   Batch 92: 1000 candles
#   Batch 93: 1000 candles
#   Batch 94: 1000 candles
#   Batch 95: 1000 candles
#   Batch 96: 1000 candles
#   Batch 97: 1000 candles
#   Batch 98: 1000 candles
#   Batch 99: 1000 candles
#   Batch 100: 1000 candles
#   Batch 101: 1000 candles
#   Batch 102: 1000 candles
#   Batch 103: 1000 candles
#   Batch 104: 1000 candles
#   Batch 105: 1000 candles
#   Batch 106: 1000 candles
#   Batch 107: 1000 candles
#   Batch 108: 1000 candles
#   Batch 109: 1000 candles
#   Batch 110: 1000 candles
#   Batch 111: 1000 candles
#   Batch 112: 1000 candles
#   Batch 113: 1000 candles
#   Batch 114: 1000 candles
#   Batch 115: 1000 candles
#   Batch 116: 1000 candles
#   Batch 117: 1000 candles
#   Batch 118: 1000 candles
#   Batch 119: 1000 candles
#   Batch 120: 1000 candles
#   Batch 121: 1000 candles
#   Batch 122: 1000 candles
#   Batch 123: 1000 candles
#   Batch 124: 1000 candles
#   Batch 125: 1000 candles
#   Batch 126: 1000 candles
#   Batch 127: 1000 candles
#   Batch 128: 1000 candles
#   Batch 129: 1000 candles
#   Batch 130: 1000 candles
#   Batch 131: 1000 candles
#   Batch 132: 1000 candles
#   Batch 133: 1000 candles
#   Batch 134: 1000 candles
#   Batch 135: 1000 candles
#   Batch 136: 1000 candles
#   Batch 137: 1000 candles
#   Batch 138: 1000 candles
#   Batch 139: 1000 candles
#   Batch 140: 1000 candles
#   Batch 141: 1000 candles
#   Batch 142: 1000 candles
#   Batch 143: 1000 candles
#   Batch 144: 1000 candles
#   Batch 145: 1000 candles
#   Batch 146: 1000 candles
#   Batch 147: 1000 candles
#   Batch 148: 1000 candles
#   Batch 149: 1000 candles
#   Batch 150: 1000 candles
#   Batch 151: 1000 candles
#   Batch 152: 1000 candles
#   Batch 153: 1000 candles
#   Batch 154: 1000 candles
#   Batch 155: 1000 candles
#   Batch 156: 1000 candles
#   Batch 157: 1000 candles
#   Batch 158: 1000 candles
#   Batch 159: 1000 candles
#   Batch 160: 1000 candles
#   Batch 161: 1000 candles
#   Batch 162: 1000 candles
#   Batch 163: 1000 candles
#   Batch 164: 1000 candles
#   Batch 165: 1000 candles
#   Batch 166: 1000 candles
#   Batch 167: 1000 candles
#   Batch 168: 1000 candles
#   Batch 169: 1000 candles
#   Batch 170: 1000 candles
#   Batch 171: 1000 candles
#   Batch 172: 1000 candles
#   Batch 173: 1000 candles
#   Batch 174: 1000 candles
#   Batch 175: 1000 candles
#   Batch 176: 1000 candles
#   Batch 177: 1000 candles
#   Batch 178: 1000 candles
#   Batch 179: 1000 candles
#   Batch 180: 1000 candles
#   Batch 181: 1000 candles
#   Batch 182: 1000 candles
#   Batch 183: 1000 candles
#   Batch 184: 1000 candles
#   Batch 185: 1000 candles
#   Batch 186: 1000 candles
#   Batch 187: 1000 candles
#   Batch 188: 1000 candles
#   Batch 189: 1000 candles
#   Batch 190: 1000 candles
#   Batch 191: 1000 candles
#   Batch 192: 1000 candles
#   Batch 193: 1000 candles
#   Batch 194: 1000 candles
#   Batch 195: 1000 candles
#   Batch 196: 1000 candles
#   Batch 197: 1000 candles
#   Batch 198: 1000 candles
#   Batch 199: 1000 candles
#   Batch 200: 1000 candles
#   Batch 201: 1000 candles
#   Batch 202: 1000 candles
#   Batch 203: 1000 candles
#   Batch 204: 1000 candles
#   Batch 205: 1000 candles
#   Batch 206: 1000 candles
#   Batch 207: 1000 candles
#   Batch 208: 1000 candles
#   Batch 209: 1000 candles
#   Batch 210: 1000 candles
#   Batch 211: 1000 candles
#   Batch 212: 1000 candles
#   Batch 213: 1000 candles
#   Batch 214: 1000 candles
#   Batch 215: 1000 candles
#   Batch 216: 1000 candles
#   Batch 217: 1000 candles
#   Batch 218: 1000 candles
#   Batch 219: 1000 candles
#   Batch 220: 1000 candles
#   Batch 221: 1000 candles
#   Batch 222: 1000 candles
#   Batch 223: 1000 candles
#   Batch 224: 1000 candles
#   Batch 225: 1000 candles
#   Batch 226: 1000 candles
#   Batch 227: 1000 candles
#   Batch 228: 1000 candles
#   Batch 229: 1000 candles
#   Batch 230: 1000 candles
#   Batch 231: 1000 candles
#   Batch 232: 1000 candles
#   Batch 233: 1000 candles
#   Batch 234: 1000 candles
#   Batch 235: 1000 candles
#   Batch 236: 1000 candles
#   Batch 237: 1000 candles
#   Batch 238: 1000 candles
#   Batch 239: 1000 candles
#   Batch 240: 1000 candles
#   Batch 241: 1000 candles
#   Batch 242: 1000 candles
#   Batch 243: 1000 candles
#   Batch 244: 1000 candles
#   Batch 245: 1000 candles
#   Batch 246: 1000 candles
#   Batch 247: 1000 candles
#   Batch 248: 1000 candles
#   Batch 249: 1000 candles
#   Batch 250: 1000 candles
#   Batch 251: 1000 candles
#   Batch 252: 1000 candles
#   Batch 253: 1000 candles
#   Batch 254: 1000 candles
#   Batch 255: 1000 candles
#   Batch 256: 1000 candles
#   Batch 257: 1000 candles
#   Batch 258: 1000 candles
#   Batch 259: 1000 candles
#   Batch 260: 1000 candles
#   Batch 261: 1000 candles
#   Batch 262: 1000 candles
#   Batch 263: 1000 candles
#   Batch 264: 1000 candles
#   Batch 265: 1000 candles
#   Batch 266: 1000 candles
#   Batch 267: 1000 candles
#   Batch 268: 1000 candles
#   Batch 269: 1000 candles
#   Batch 270: 1000 candles
#   Batch 271: 1000 candles
#   Batch 272: 1000 candles
#   Batch 273: 1000 candles
#   Batch 274: 1000 candles
#   Batch 275: 1000 candles
#   Batch 276: 1000 candles
#   Batch 277: 1000 candles
#   Batch 278: 1000 candles
#   Batch 279: 1000 candles
#   Batch 280: 1000 candles
#   Batch 281: 1000 candles
#   Batch 282: 1000 candles
#   Batch 283: 1000 candles
#   Batch 284: 1000 candles
#   Batch 285: 1000 candles
#   Batch 286: 1000 candles
#   Batch 287: 1000 candles
#   Batch 288: 1000 candles
#   Batch 289: 1000 candles
#   Batch 290: 1000 candles
#   Batch 291: 1000 candles
#   Batch 292: 1000 candles
#   Batch 293: 1000 candles
#   Batch 294: 1000 candles
#   Batch 295: 1000 candles
#   Batch 296: 1000 candles
#   Batch 297: 1000 candles
#   Batch 298: 1000 candles
#   Batch 299: 1000 candles
#   Batch 300: 1000 candles
#   Batch 301: 1000 candles
#   Batch 302: 1000 candles
#   Batch 303: 1000 candles
#   Batch 304: 1000 candles
#   Batch 305: 1000 candles
#   Batch 306: 1000 candles
#   Batch 307: 1000 candles
#   Batch 308: 1000 candles
#   Batch 309: 1000 candles
#   Batch 310: 1000 candles
#   Batch 311: 1000 candles
#   Batch 312: 1000 candles
#   Batch 313: 1000 candles
#   Batch 314: 1000 candles
#   Batch 315: 1000 candles
#   Batch 316: 1000 candles
#   Batch 317: 1000 candles
#   Batch 318: 1000 candles
#   Batch 319: 1000 candles
#   Batch 320: 1000 candles
#   Batch 321: 1000 candles
#   Batch 322: 1000 candles
#   Batch 323: 1000 candles
#   Batch 324: 1000 candles
#   Batch 325: 1000 candles
#   Batch 326: 1000 candles
#   Batch 327: 1000 candles
#   Batch 328: 1000 candles
#   Batch 329: 1000 candles
#   Batch 330: 1000 candles
#   Batch 331: 1000 candles
#   Batch 332: 1000 candles
#   Batch 333: 1000 candles
#   Batch 334: 1000 candles
#   Batch 335: 1000 candles
#   Batch 336: 1000 candles
#   Batch 337: 1000 candles
#   Batch 338: 1000 candles
#   Batch 339: 1000 candles
#   Batch 340: 1000 candles
#   Batch 341: 1000 candles
#   Batch 342: 1000 candles
#   Batch 343: 1000 candles
#   Batch 344: 1000 candles
#   Batch 345: 1000 candles
#   Batch 346: 1000 candles
#   Batch 347: 1000 candles
#   Batch 348: 1000 candles
#   Batch 349: 1000 candles
#   Batch 350: 1000 candles
#   Batch 351: 1000 candles
#   Batch 352: 1000 candles
#   Batch 353: 1000 candles
#   Batch 354: 1000 candles
#   Batch 355: 1000 candles
#   Batch 356: 1000 candles
#   Batch 357: 1000 candles
#   Batch 358: 1000 candles
#   Batch 359: 1000 candles
#   Batch 360: 1000 candles
#   Batch 361: 1000 candles
#   Batch 362: 1000 candles
#   Batch 363: 1000 candles
#   Batch 364: 1000 candles
#   Batch 365: 1000 candles
#   Batch 366: 1000 candles
#   Batch 367: 1000 candles
#   Batch 368: 1000 candles
#   Batch 369: 1000 candles
#   Batch 370: 1000 candles
#   Batch 371: 1000 candles
#   Batch 372: 1000 candles
#   Batch 373: 1000 candles
#   Batch 374: 1000 candles
#   Batch 375: 1000 candles
#   Batch 376: 1000 candles
#   Batch 377: 1000 candles
#   Batch 378: 1000 candles
#   Batch 379: 1000 candles
#   Batch 380: 1000 candles
#   Batch 381: 1000 candles
#   Batch 382: 1000 candles
#   Batch 383: 1000 candles
#   Batch 384: 1000 candles
#   Batch 385: 1000 candles
#   Batch 386: 1000 candles
#   Batch 387: 1000 candles
#   Batch 388: 1000 candles
#   Batch 389: 1000 candles
#   Batch 390: 1000 candles
#   Batch 391: 1000 candles
#   Batch 392: 1000 candles
#   Batch 393: 1000 candles
#   Batch 394: 1000 candles
#   Batch 395: 1000 candles
#   Batch 396: 1000 candles
#   Batch 397: 1000 candles
#   Batch 398: 1000 candles
#   Batch 399: 1000 candles
#   Batch 400: 1000 candles
#   Batch 401: 1000 candles
#   Batch 402: 1000 candles
#   Batch 403: 1000 candles
#   Batch 404: 1000 candles
#   Batch 405: 1000 candles
#   Batch 406: 1000 candles
#   Batch 407: 1000 candles
#   Batch 408: 1000 candles
#   Batch 409: 1000 candles
#   Batch 410: 1000 candles
#   Batch 411: 1000 candles
#   Batch 412: 1000 candles
#   Batch 413: 1000 candles
#   Batch 414: 1000 candles
#   Batch 415: 1000 candles
#   Batch 416: 1000 candles
#   Batch 417: 1000 candles
#   Batch 418: 1000 candles
#   Batch 419: 1000 candles
#   Batch 420: 1000 candles
#   Batch 421: 1000 candles
#   Batch 422: 1000 candles
#   Batch 423: 1000 candles
#   Batch 424: 1000 candles
#   Batch 425: 1000 candles
#   Batch 426: 1000 candles
#   Batch 427: 1000 candles
#   Batch 428: 1000 candles
#   Batch 429: 1000 candles
#   Batch 430: 1000 candles
#   Batch 431: 1000 candles
#   Batch 432: 1000 candles
#   Batch 433: 1000 candles
#   Batch 434: 1000 candles
#   Batch 435: 1000 candles
#   Batch 436: 1000 candles
#   Batch 437: 1000 candles
#   Batch 438: 1000 candles
#   Batch 439: 1000 candles
#   Batch 440: 1000 candles
#   Batch 441: 1000 candles
#   Batch 442: 1000 candles
#   Batch 443: 1000 candles
#   Batch 444: 1000 candles
#   Batch 445: 1000 candles
#   Batch 446: 1000 candles
#   Batch 447: 1000 candles
#   Batch 448: 1000 candles
#   Batch 449: 1000 candles
#   Batch 450: 1000 candles
#   Batch 451: 1000 candles
#   Batch 452: 1000 candles
#   Batch 453: 1000 candles
#   Batch 454: 1000 candles
#   Batch 455: 1000 candles
#   Batch 456: 1000 candles
#   Batch 457: 1000 candles
#   Batch 458: 1000 candles
#   Batch 459: 1000 candles
#   Batch 460: 1000 candles
#   Batch 461: 1000 candles
#   Batch 462: 1000 candles
#   Batch 463: 1000 candles
#   Batch 464: 1000 candles
#   Batch 465: 1000 candles
#   Batch 466: 1000 candles
#   Batch 467: 1000 candles
#   Batch 468: 1000 candles
#   Batch 469: 1000 candles
#   Batch 470: 1000 candles
#   Batch 471: 1000 candles
#   Batch 472: 1000 candles
#   Batch 473: 1000 candles
#   Batch 474: 1000 candles
#   Batch 475: 1000 candles
#   Batch 476: 1000 candles
#   Batch 477: 1000 candles
#   Batch 478: 1000 candles
#   Batch 479: 1000 candles
#   Batch 480: 1000 candles
#   Batch 481: 1000 candles
#   Batch 482: 1000 candles
#   Batch 483: 1000 candles
#   Batch 484: 1000 candles
#   Batch 485: 1000 candles
#   Batch 486: 1000 candles
#   Batch 487: 1000 candles
#   Batch 488: 1000 candles
#   Batch 489: 1000 candles
#   Batch 490: 1000 candles
#   Batch 491: 1000 candles
#   Batch 492: 1000 candles
#   Batch 493: 1000 candles
#   Batch 494: 1000 candles
#   Batch 495: 1000 candles
#   Batch 496: 1000 candles
#   Batch 497: 1000 candles
#   Batch 498: 1000 candles
#   Batch 499: 1000 candles
#   Batch 500: 1000 candles
#   Batch 501: 1000 candles
#   Batch 502: 1000 candles
#   Batch 503: 1000 candles
#   Batch 504: 1000 candles
#   Batch 505: 1000 candles
#   Batch 506: 1000 candles
#   Batch 507: 1000 candles
#   Batch 508: 1000 candles
#   Batch 509: 1000 candles
#   Batch 510: 1000 candles
#   Batch 511: 1000 candles
#   Batch 512: 1000 candles
#   Batch 513: 1000 candles
#   Batch 514: 1000 candles
#   Batch 515: 1000 candles
#   Batch 516: 1000 candles
#   Batch 517: 1000 candles
#   Batch 518: 1000 candles
#   Batch 519: 1000 candles
#   Batch 520: 1000 candles
#   Batch 521: 1000 candles
#   Batch 522: 1000 candles
#   Batch 523: 1000 candles
#   Batch 524: 160 candles
#   Completed METISUSDT: 524160 total candles
# Saved 524160 candles for METISUSDT to /home/zac/back-testing/data/METISUSDT_1m_candles.csv
#
# === Collection Summary ===
# Successfully collected: 3
# Failed: 0
# Total symbols processed: 3
# Total candles collected: 1309759
# Data saved to: /home/zac/back-testing/data
# Example 1 ready (test with 3 symbols, last 52 weeks, 2 concurrent)
# Saved 524160 candles for METISUSDT to /home/zac/back-testing/data/METISUSDT_1m_candles.csv
#
# === Collection Summary ===
# Successfully collected: 3
# Failed: 0
# Total symbols processed: 3
# Total candles collected: 1309759
# Data saved to: /home/zac/back-testing/data
# Example 1 ready (test with 3 symbols, last 52 weeks, 2 concurrent)
