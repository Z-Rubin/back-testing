# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import warnings
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading

# %%
# Load data for all symbols
from backtester.data_loader import DataLoader

# Initialize DataLoader
loader = DataLoader(base_path="../data")
SYMBOLS = None

if SYMBOLS is None:
    data_path = Path("../data")
    SYMBOLS = [f.stem for f in data_path.glob("*USDT.csv")]


dfs = []
for symbol in SYMBOLS:
    dfs.append(loader.load_symbol(symbol))

# %%
# Give summary of loaded data
# make a df with the characterists of each df. number of candles, start, end, price range etc
